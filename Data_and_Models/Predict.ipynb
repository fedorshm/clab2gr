# %% [markdown]
# Обработка test_1_grup_Ivan

# %%
import os

# Пути к папкам
png_dir = "C:\\Users\\Vito\\Jupyter\\Models\\test_1_grup_Ivan\\images"  # Папка с PNG
json_dir = "C:\\Users\\Vito\\Jupyter\\Models\\test_1_grup_Ivan\\json"  # Папка с JSON

# Получаем базовые имена файлов (без расширений)
png_files = {os.path.splitext(f)[0] for f in os.listdir(png_dir) if f.endswith(".png")}
json_files = {os.path.splitext(f)[0] for f in os.listdir(json_dir) if f.endswith(".json")}

# Выявляем лишние файлы
extra_png_files = png_files - json_files  # PNG, которых нет в JSON
extra_json_files = json_files - png_files  # JSON, которых нет в PNG

# Вывод результата
print(f"Лишние PNG файлы ({len(extra_png_files)}):", extra_png_files)
print(f"Лишние JSON файлы ({len(extra_json_files)}):", extra_json_files)

# Записать результат в файлы для анализа
with open("extra_png_files.txt", "w") as f:
    f.write("\n".join(sorted(extra_png_files)))

with open("extra_json_files.txt", "w") as f:
    f.write("\n".join(sorted(extra_json_files)))

print("Проверка завершена. Результаты записаны в extra_png_files.txt и extra_json_files.txt.")
# Out:
# Лишние PNG файлы (0): set()
# Лишние JSON файлы (0): set()
# Проверка завершена. Результаты записаны в extra_png_files.txt и extra_json_files.txt.

# %%
# Предобработка данных
import os
import json

# Папки
json_dir = "C:\\Users\\Vito\\Jupyter\\Models\\test_1_grup_Ivan\\json"  # Путь к папке с JSON
images_dir = "C:\\Users\\Vito\\Jupyter\\Models\\test_1_grup_Ivan\\images"    # Путь к изображениям
output_dir = "C:\\Users\\Vito\\Jupyter\\Models\\test_1_grup_Ivan\\labels"  # Папка для сохранения YOLO разметки

# Словарь классов
class_mapping = {
    "title": 0,
    "paragraph": 1,
    "table": 2,
    "picture": 3,
    "table_signature": 4,
    "picture_signature": 5,
    "numbered_list": 6,
    "marked_list": 7,
    "header": 8,
    "footer": 9,
    "footnote": 10,
    "formula": 11
}

# Создаем выходную папку
os.makedirs(output_dir, exist_ok=True)

# Функция для нормализации координат
def normalize_bbox(bbox, img_width, img_height):
    x1, y1, x2, y2 = bbox
    x_center = (x1 + x2) / 2 / img_width
    y_center = (y1 + y2) / 2 / img_height
    width = (x2 - x1) / img_width
    height = (y2 - y1) / img_height
    return x_center, y_center, width, height

# Проход по JSON файлам
for json_file in os.listdir(json_dir):
    if json_file.endswith(".json"):
        # Открываем JSON файл
        with open(os.path.join(json_dir, json_file), "r") as f:
            data = json.load(f)
        
        img_width = data["image_width"]
        img_height = data["image_height"]
        txt_filename = os.path.splitext(json_file)[0] + ".txt"
        txt_path = os.path.join(output_dir, txt_filename)
        
        # Запись данных в YOLO формат
        with open(txt_path, "w") as txt_file:
            for class_name, bboxes in data.items():
                if class_name in class_mapping:
                    class_id = class_mapping[class_name]
                    for bbox in bboxes:
                        x_center, y_center, width, height = normalize_bbox(bbox, img_width, img_height)
                        txt_file.write(f"{class_id} {x_center} {y_center} {width} {height}\n")

# %%
import os
import cv2
from ultralytics import YOLO
from PIL import Image
from pathlib import Path
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import average_precision_score
import numpy as np

# Пути
input_images_dir = "C:\\Users\\Vito\\Jupyter\\Models\\test_1_grup_Ivan\\images"  # Папка с изображениями документов
labels_dir = "C:\\Users\\Vito\\Jupyter\\Models\\test_1_grup_Ivan\\labels"  # Папка с разметкой YOLO
output_images_dir = "C:\\Users\\Vito\\Jupyter\\Models\\test_1_grup_Ivan\\test_results"  # Папка для аннотированных изображений

# Создаём папку для аннотированных изображений, если она не существует
os.makedirs(output_images_dir, exist_ok=True)

# Загружаем модель YOLO
model = YOLO("C:\\Users\\Vito\\Jupyter\\Models\\runs YOLO11s datasetv3 aug imgsz=960\\detect\\train\\weights\\best.pt")

# Настройка кастомных порогов для каждого класса
custom_confidences = {
    0: 0.3,  # title
    1: 0.1,  # paragraph
    9: 0.1, # footer
    11: 0.1, # formula
    10: 0.8, # footnote
    6: 0.4, # numbered_list
    7: 0.4  # marked_list
}

# Список всех изображений в папке
image_files = [f for f in os.listdir(input_images_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
image_files.sort()  # Сортируем для упорядоченности

# 1. Обрабатываем изображения моделью YOLO и визуализируем предсказания с кастомными порогами
annotated_images = []
y_true, y_pred = [], []  # Для метрик

for image_file in image_files:
    image_path = os.path.join(input_images_dir, image_file)
    label_path = os.path.join(labels_dir, Path(image_file).stem + ".txt")  # Соответствующий файл разметки
    
    img = cv2.imread(image_path)

    # Применяем модель YOLO
    results = model.predict(source=img, conf=0.4, iou=0.51, save=False)
    
    # Фильтруем предсказания на основе кастомных порогов для классов
    filtered_boxes = []
    for result in results:
        for box in result.boxes:
            cls = int(box.cls)  # Класс объекта
            conf = float(box.conf)  # Уверенность объекта

            # Проверяем, превышает ли уверенность кастомный порог для данного класса
            if cls in custom_confidences:
                if conf >= custom_confidences[cls]:
                    filtered_boxes.append(box)
            else:
                # Используем общий порог (например, 0.4) для классов, для которых не задан кастомный порог
                if conf >= 0.4:
                    filtered_boxes.append(box)

        # Применяем отфильтрованные боксы для визуализации
        result.boxes = filtered_boxes

    # Наносим рамки на изображение
    annotated_img = results[0].plot()  # Визуализируем предсказания (аннотированное изображение)
    annotated_image_path = os.path.join(output_images_dir, image_file)
    cv2.imwrite(annotated_image_path, annotated_img)
    annotated_images.append(annotated_image_path)

    # Сравниваем с разметкой для метрик
    if os.path.exists(label_path):
        # Чтение разметки (ground truth)
        with open(label_path, "r") as f:
            true_boxes = [line.strip().split() for line in f.readlines()]
            true_classes = [int(box[0]) for box in true_boxes]  # Классы из разметки

        # Собираем предсказания
        pred_classes = [int(box.cls) for box in filtered_boxes]

        # Добавляем в список для метрик
        y_true.extend(true_classes)
        y_pred.extend(pred_classes)

# 2. Рассчитываем метрики
precision, recall, f1, _ = precision_recall_fscore_support(y_true, y_pred, average="weighted")
mIoU = average_precision_score(y_true, y_pred)  # Оценка mAP50-95 (приближённая)
fitness = (precision + recall + f1) / 3  # Условная метрика для общего качества

# Вывод метрик
print(f"Precision: {precision:.6f}")
print(f"Recall: {recall:.6f}")
print(f"F1 Score: {f1:.6f}")
print(f"mIoU (mAP50-95): {mIoU:.6f}")
print(f"Fitness: {fitness:.6f}")
# Out:
# 0: 768x960 1 paragraph, 261.9ms
# Speed: 9.0ms preprocess, 261.9ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 table, 264.3ms
# Speed: 8.0ms preprocess, 264.3ms inference, 2.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 274.7ms
# Speed: 8.0ms preprocess, 274.7ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x704 1 title, 1 numbered_list, 256.0ms
# Speed: 9.1ms preprocess, 256.0ms inference, 1.3ms postprocess per image at shape (1, 3, 960, 704)
#
# 0: 960x768 5 paragraphs, 1 table, 2 numbered_lists, 1 header, 286.8ms
# Speed: 8.9ms preprocess, 286.8ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 1 table, 3 marked_lists, 1 header, 265.3ms
# Speed: 11.9ms preprocess, 265.3ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 2 tables, 1 numbered_list, 1 marked_list, 1 header, 270.2ms
# Speed: 8.3ms preprocess, 270.2ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 table, 1 marked_list, 1 header, 246.4ms
# Speed: 8.5ms preprocess, 246.4ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 5 paragraphs, 1 table, 1 picture, 1 numbered_list, 1 header, 226.1ms
# Speed: 8.0ms preprocess, 226.1ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 5 paragraphs, 1 picture, 1 header, 243.7ms
# Speed: 7.0ms preprocess, 243.7ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 1 picture, 1 header, 291.4ms
# Speed: 8.4ms preprocess, 291.4ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 2 paragraphs, 1 table, 1 header, 290.9ms
# Speed: 9.3ms preprocess, 290.9ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 table, 1 header, 271.1ms
# Speed: 9.1ms preprocess, 271.1ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 5 paragraphs, 1 table, 1 header, 260.5ms
# Speed: 7.5ms preprocess, 260.5ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 4 paragraphs, 1 picture, 2 marked_lists, 1 header, 268.8ms
# Speed: 8.3ms preprocess, 268.8ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 3 paragraphs, 1 table, 2 pictures, 1 header, 243.6ms
# Speed: 7.0ms preprocess, 243.6ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x704 1 title, 1 numbered_list, 1 header, 219.7ms
# Speed: 15.6ms preprocess, 219.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 704)
#
# 0: 768x960 1 title, 3 paragraphs, 1 marked_list, 1 header, 1 footnote, 261.0ms
# Speed: 0.0ms preprocess, 261.0ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 5 paragraphs, 1 header, 231.7ms
# Speed: 0.0ms preprocess, 231.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 5 paragraphs, 1 marked_list, 1 header, 283.6ms
# Speed: 16.4ms preprocess, 283.6ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 2 titles, 5 paragraphs, 3 marked_lists, 1 header, 234.5ms
# Speed: 17.7ms preprocess, 234.5ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 5 paragraphs, 1 table, 2 marked_lists, 1 header, 235.1ms
# Speed: 0.0ms preprocess, 235.1ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 1 paragraph, 1 table, 1 header, 219.8ms
# Speed: 15.7ms preprocess, 219.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 titles, 3 paragraphs, 2 pictures, 1 header, 216.0ms
# Speed: 13.0ms preprocess, 216.0ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 table, 2 numbered_lists, 1 marked_list, 267.1ms
# Speed: 10.5ms preprocess, 267.1ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 table, 1 marked_list, 298.5ms
# Speed: 0.0ms preprocess, 298.5ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 7 paragraphs, 1 table, 1 picture, 1 numbered_list, 1 marked_list, 235.2ms
# Speed: 0.0ms preprocess, 235.2ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 1 table, 1 numbered_list, 1 marked_list, 235.3ms
# Speed: 0.0ms preprocess, 235.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 5 paragraphs, 1 picture, 1 picture_signature, 240.3ms
# Speed: 15.7ms preprocess, 240.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 4 paragraphs, 2 pictures, 283.0ms
# Speed: 0.0ms preprocess, 283.0ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 3 paragraphs, 1 table, 1 marked_list, 236.6ms
# Speed: 11.8ms preprocess, 236.6ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 table, 1 marked_list, 235.9ms
# Speed: 15.6ms preprocess, 235.9ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 225.6ms
# Speed: 9.5ms preprocess, 225.6ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 4 paragraphs, 1 numbered_list, 235.4ms
# Speed: 15.6ms preprocess, 235.4ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 table, 1 numbered_list, 2 marked_lists, 1 header, 234.1ms
# Speed: 0.0ms preprocess, 234.1ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 4 paragraphs, 1 picture, 1 numbered_list, 220.9ms
# Speed: 15.6ms preprocess, 220.9ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 3 paragraphs, 1 picture, 2 marked_lists, 244.9ms
# Speed: 15.6ms preprocess, 244.9ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 table, 1 marked_list, 236.6ms
# Speed: 15.6ms preprocess, 236.6ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 table, 2 pictures, 1 marked_list, 236.5ms
# Speed: 0.0ms preprocess, 236.5ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 table, 1 header, 228.7ms
# Speed: 7.8ms preprocess, 228.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 paragraph, 251.8ms
# Speed: 0.0ms preprocess, 251.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 1 marked_list, 232.2ms
# Speed: 7.9ms preprocess, 232.2ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 numbered_list, 219.7ms
# Speed: 15.6ms preprocess, 219.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x704 1 title, 1 paragraph, 1 numbered_list, 252.0ms
# Speed: 0.0ms preprocess, 252.0ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 704)
#
# 0: 960x768 6 paragraphs, 1 picture, 239.3ms
# Speed: 0.0ms preprocess, 239.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 table, 1 marked_list, 219.7ms
# Speed: 15.6ms preprocess, 219.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 2 paragraphs, 236.2ms
# Speed: 0.0ms preprocess, 236.2ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 4 paragraphs, 235.4ms
# Speed: 0.0ms preprocess, 235.4ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 5 paragraphs, 234.2ms
# Speed: 0.0ms preprocess, 234.2ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 2 paragraphs, 1 picture, 235.7ms
# Speed: 0.0ms preprocess, 235.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 title, 1 paragraph, 227.6ms
# Speed: 8.5ms preprocess, 227.6ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 5 paragraphs, 1 table, 2 marked_lists, 253.5ms
# Speed: 15.6ms preprocess, 253.5ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 5 paragraphs, 2 pictures, 236.7ms
# Speed: 15.6ms preprocess, 236.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 5 paragraphs, 1 marked_list, 233.9ms
# Speed: 15.6ms preprocess, 233.9ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 4 paragraphs, 1 table, 1 picture, 219.2ms
# Speed: 15.7ms preprocess, 219.2ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 1 table, 236.3ms
# Speed: 0.0ms preprocess, 236.3ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 title, 3 paragraphs, 1 picture, 2 marked_lists, 251.2ms
# Speed: 15.6ms preprocess, 251.2ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 numbered_lists, 220.0ms
# Speed: 15.6ms preprocess, 220.0ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 4 paragraphs, 1 picture, 1 numbered_list, 236.1ms
# Speed: 0.0ms preprocess, 236.1ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 8 paragraphs, 220.5ms
# Speed: 12.5ms preprocess, 220.5ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 239.3ms
# Speed: 15.6ms preprocess, 239.3ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 3 paragraphs, 1 picture, 252.0ms
# Speed: 0.0ms preprocess, 252.0ms inference, 10.1ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 6 paragraphs, 1 marked_list, 235.5ms
# Speed: 15.6ms preprocess, 235.5ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 2 paragraphs, 1 picture, 1 numbered_list, 236.1ms
# Speed: 15.6ms preprocess, 236.1ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 2 titles, 1 paragraph, 2 pictures, 235.7ms
# Speed: 0.0ms preprocess, 235.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 paragraph, 1 numbered_list, 236.1ms
# Speed: 0.0ms preprocess, 236.1ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 picture, 235.3ms
# Speed: 0.0ms preprocess, 235.3ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 title, 4 paragraphs, 1 picture, 1 marked_list, 220.7ms
# Speed: 15.0ms preprocess, 220.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 4 paragraphs, 1 table, 1 picture, 1 numbered_list, 235.7ms
# Speed: 0.0ms preprocess, 235.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 picture, 267.2ms
# Speed: 15.9ms preprocess, 267.2ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 title, 1 paragraph, 1 picture, 1 numbered_list, 283.3ms
# Speed: 3.4ms preprocess, 283.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 266.6ms
# Speed: 0.0ms preprocess, 266.6ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 title, 1 table, 284.5ms
# Speed: 0.0ms preprocess, 284.5ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 title, 2 paragraphs, 2 marked_lists, 268.2ms
# Speed: 15.6ms preprocess, 268.2ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x704 1 title, 1 paragraph, 1 numbered_list, 219.7ms
# Speed: 15.6ms preprocess, 219.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 704)
#
# 0: 960x768 1 title, 5 paragraphs, 1 numbered_list, 235.7ms
# Speed: 15.7ms preprocess, 235.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 table, 1 numbered_list, 267.0ms
# Speed: 15.6ms preprocess, 267.0ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 1 table, 234.4ms
# Speed: 17.1ms preprocess, 234.4ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 5 paragraphs, 1 picture, 235.8ms
# Speed: 14.5ms preprocess, 235.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 2 paragraphs, 1 table, 1 picture, 251.6ms
# Speed: 0.0ms preprocess, 251.6ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 1 paragraph, 271.1ms
# Speed: 18.2ms preprocess, 271.1ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 5 paragraphs, 1 table, 2 pictures, 1 footer, 268.0ms
# Speed: 8.0ms preprocess, 268.0ms inference, 15.6ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 table, 1 picture, 1 footer, 266.7ms
# Speed: 12.5ms preprocess, 266.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 5 paragraphs, 1 picture, 1 numbered_list, 2 marked_lists, 1 footer, 264.6ms
# Speed: 18.9ms preprocess, 264.6ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 3 paragraphs, 1 table, 1 footer, 273.6ms
# Speed: 9.7ms preprocess, 273.6ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 3 paragraphs, 1 table, 1 footer, 234.8ms
# Speed: 0.0ms preprocess, 234.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 paragraph, 2 pictures, 1 footer, 267.3ms
# Speed: 10.8ms preprocess, 267.3ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 table, 1 footer, 254.1ms
# Speed: 12.5ms preprocess, 254.1ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 paragraph, 1 table, 1 footer, 252.1ms
# Speed: 15.6ms preprocess, 252.1ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 1 table, 1 picture, 1 footer, 235.8ms
# Speed: 15.6ms preprocess, 235.8ms inference, 4.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 5 paragraphs, 1 picture, 2 marked_lists, 1 footer, 220.2ms
# Speed: 8.0ms preprocess, 220.2ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 5 paragraphs, 1 marked_list, 1 footer, 235.7ms
# Speed: 16.0ms preprocess, 235.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 1 table, 1 picture, 1 numbered_list, 1 marked_list, 1 footer, 251.4ms
# Speed: 0.0ms preprocess, 251.4ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 footer, 278.6ms
# Speed: 15.2ms preprocess, 278.6ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x704 2 paragraphs, 1 numbered_list, 1 footer, 248.6ms
# Speed: 6.6ms preprocess, 248.6ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 704)
#
# 0: 960x768 1 title, 5 paragraphs, 1 picture, 1 footer, 268.9ms
# Speed: 0.0ms preprocess, 268.9ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 table, 1 numbered_list, 1 footer, 245.0ms
# Speed: 6.6ms preprocess, 245.0ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 picture, 1 marked_list, 1 footer, 283.1ms
# Speed: 12.3ms preprocess, 283.1ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 marked_list, 1 footer, 249.3ms
# Speed: 17.9ms preprocess, 249.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 title, 2 paragraphs, 1 picture, 1 footer, 235.7ms
# Speed: 15.6ms preprocess, 235.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 4 paragraphs, 1 numbered_list, 1 footer, 236.0ms
# Speed: 15.8ms preprocess, 236.0ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 5 paragraphs, 1 marked_list, 1 footer, 219.7ms
# Speed: 15.6ms preprocess, 219.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 1 table, 1 marked_list, 252.7ms
# Speed: 15.7ms preprocess, 252.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 2 paragraphs, 1 table, 1 header, 246.2ms
# Speed: 21.6ms preprocess, 246.2ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 4 paragraphs, 1 table, 1 numbered_list, 1 header, 268.3ms
# Speed: 0.0ms preprocess, 268.3ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 header, 267.2ms
# Speed: 0.0ms preprocess, 267.2ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 2 paragraphs, 2 tables, 251.3ms
# Speed: 15.7ms preprocess, 251.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 titles, 1 paragraph, 1 table, 236.6ms
# Speed: 0.0ms preprocess, 236.6ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 5 paragraphs, 1 table, 1 picture, 2 marked_lists, 235.6ms
# Speed: 0.0ms preprocess, 235.6ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 1 paragraph, 1 table, 252.0ms
# Speed: 0.0ms preprocess, 252.0ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 paragraph, 1 table, 1 header, 236.6ms
# Speed: 0.0ms preprocess, 236.6ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 table, 1 header, 235.8ms
# Speed: 0.0ms preprocess, 235.8ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 3 paragraphs, 2 tables, 1 picture, 1 marked_list, 1 header, 315.0ms
# Speed: 15.6ms preprocess, 315.0ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 4 paragraphs, 232.6ms
# Speed: 0.0ms preprocess, 232.6ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 4 paragraphs, 1 marked_list, 1 header, 235.1ms
# Speed: 16.6ms preprocess, 235.1ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 title, 2 paragraphs, 1 table, 1 picture, 1 marked_list, 268.5ms
# Speed: 0.0ms preprocess, 268.5ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 2 tables, 1 numbered_list, 235.3ms
# Speed: 0.0ms preprocess, 235.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 3 paragraphs, 1 marked_list, 204.5ms
# Speed: 16.0ms preprocess, 204.5ms inference, 15.7ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x704 3 paragraphs, 1 numbered_list, 204.6ms
# Speed: 0.0ms preprocess, 204.6ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 704)
#
# 0: 960x768 8 paragraphs, 1 numbered_list, 220.2ms
# Speed: 0.0ms preprocess, 220.2ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 titles, 3 paragraphs, 236.2ms
# Speed: 0.0ms preprocess, 236.2ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 title, 4 paragraphs, 1 picture, 1 header, 219.7ms
# Speed: 13.0ms preprocess, 219.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 title, 3 paragraphs, 1 marked_list, 220.3ms
# Speed: 14.0ms preprocess, 220.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 3 paragraphs, 1 table, 1 marked_list, 1 header, 234.9ms
# Speed: 0.0ms preprocess, 234.9ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 4 paragraphs, 2 numbered_lists, 1 header, 235.3ms
# Speed: 0.0ms preprocess, 235.3ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 4 paragraphs, 1 header, 235.7ms
# Speed: 0.0ms preprocess, 235.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 title, 1 paragraph, 1 table, 1 picture, 220.2ms
# Speed: 15.6ms preprocess, 220.2ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 title, 9 paragraphs, 1 picture, 250.9ms
# Speed: 0.0ms preprocess, 250.9ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 titles, 2 paragraphs, 282.8ms
# Speed: 0.0ms preprocess, 282.8ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 2 titles, 1 paragraph, 1 picture, 219.6ms
# Speed: 15.6ms preprocess, 219.6ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 titles, 3 paragraphs, 1 numbered_list, 230.4ms
# Speed: 5.0ms preprocess, 230.4ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 3 paragraphs, 1 table, 1 numbered_list, 283.0ms
# Speed: 14.0ms preprocess, 283.0ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 6 paragraphs, 1 table, 1 picture, 249.4ms
# Speed: 0.0ms preprocess, 249.4ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 1 paragraph, 1 table, 268.6ms
# Speed: 15.7ms preprocess, 268.6ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 4 paragraphs, 1 table, 1 marked_list, 235.9ms
# Speed: 0.0ms preprocess, 235.9ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 3 paragraphs, 1 picture, 250.9ms
# Speed: 0.0ms preprocess, 250.9ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 2 paragraphs, 2 pictures, 250.4ms
# Speed: 15.6ms preprocess, 250.4ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 title, 4 paragraphs, 1 numbered_list, 235.3ms
# Speed: 0.0ms preprocess, 235.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 titles, 2 paragraphs, 229.0ms
# Speed: 0.0ms preprocess, 229.0ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 5 paragraphs, 1 table, 221.1ms
# Speed: 0.0ms preprocess, 221.1ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 1 picture, 236.5ms
# Speed: 0.0ms preprocess, 236.5ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 2 titles, 3 paragraphs, 1 picture, 219.7ms
# Speed: 0.0ms preprocess, 219.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 title, 2 paragraphs, 2 pictures, 251.7ms
# Speed: 15.7ms preprocess, 251.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 5 paragraphs, 1 table, 2 pictures, 252.5ms
# Speed: 10.0ms preprocess, 252.5ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 1 table, 236.2ms
# Speed: 15.6ms preprocess, 236.2ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x704 1 title, 2 paragraphs, 1 numbered_list, 235.8ms
# Speed: 0.0ms preprocess, 235.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 704)
#
# 0: 960x768 1 title, 4 paragraphs, 1 picture, 1 marked_list, 221.0ms
# Speed: 0.0ms preprocess, 221.0ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 8 paragraphs, 1 numbered_list, 269.8ms
# Speed: 16.3ms preprocess, 269.8ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 4 paragraphs, 298.7ms
# Speed: 15.6ms preprocess, 298.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 3 titles, 3 paragraphs, 1 picture, 1 numbered_list, 244.7ms
# Speed: 8.1ms preprocess, 244.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 titles, 2 paragraphs, 256.0ms
# Speed: 11.2ms preprocess, 256.0ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 title, 3 paragraphs, 1 picture, 250.9ms
# Speed: 0.0ms preprocess, 250.9ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 title, 2 paragraphs, 1 marked_list, 284.2ms
# Speed: 16.5ms preprocess, 284.2ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 title, 5 paragraphs, 1 picture, 1 footer, 219.9ms
# Speed: 15.6ms preprocess, 219.9ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 3 paragraphs, 1 table, 1 picture, 1 footer, 237.0ms
# Speed: 13.0ms preprocess, 237.0ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 1 paragraph, 1 table, 1 footer, 219.6ms
# Speed: 15.6ms preprocess, 219.6ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 table, 1 numbered_list, 1 footer, 220.5ms
# Speed: 15.6ms preprocess, 220.5ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 table, 1 marked_list, 1 footer, 235.9ms
# Speed: 0.0ms preprocess, 235.9ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 5 paragraphs, 1 picture, 1 numbered_list, 2 marked_lists, 1 footer, 221.2ms
# Speed: 0.0ms preprocess, 221.2ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 3 paragraphs, 2 tables, 2 marked_lists, 1 footer, 220.1ms
# Speed: 15.6ms preprocess, 220.1ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 1 paragraph, 1 table, 220.6ms
# Speed: 9.5ms preprocess, 220.6ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 3 paragraphs, 1 picture, 1 footer, 210.0ms
# Speed: 10.7ms preprocess, 210.0ms inference, 15.6ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 1 paragraph, 1 table, 1 footer, 228.1ms
# Speed: 0.0ms preprocess, 228.1ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 4 paragraphs, 1 picture, 1 numbered_list, 1 footer, 315.6ms
# Speed: 13.1ms preprocess, 315.6ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 2 paragraphs, 1 footer, 252.8ms
# Speed: 13.1ms preprocess, 252.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 2 paragraphs, 1 table, 1 footer, 267.8ms
# Speed: 15.7ms preprocess, 267.8ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 2 paragraphs, 3 tables, 1 marked_list, 1 footer, 230.8ms
# Speed: 6.0ms preprocess, 230.8ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 table, 1 footer, 220.5ms
# Speed: 13.0ms preprocess, 220.5ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 5 paragraphs, 1 picture, 1 footer, 236.6ms
# Speed: 14.6ms preprocess, 236.6ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 footer, 267.7ms
# Speed: 15.7ms preprocess, 267.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x704 1 title, 1 paragraph, 1 numbered_list, 1 footer, 220.5ms
# Speed: 16.0ms preprocess, 220.5ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 704)
#
# 0: 960x768 7 paragraphs, 1 picture, 1 marked_list, 1 footer, 339.2ms
# Speed: 6.5ms preprocess, 339.2ms inference, 0.6ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 1 table, 1 marked_list, 1 footer, 252.2ms
# Speed: 22.4ms preprocess, 252.2ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 titles, 6 paragraphs, 2 tables, 1 marked_list, 264.3ms
# Speed: 13.5ms preprocess, 264.3ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 298.3ms
# Speed: 9.9ms preprocess, 298.3ms inference, 2.2ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 8 paragraphs, 2 tables, 1 footer, 252.0ms
# Speed: 9.8ms preprocess, 252.0ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 6 paragraphs, 1 picture, 1 numbered_list, 1 footer, 228.9ms
# Speed: 9.3ms preprocess, 228.9ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 5 paragraphs, 2 pictures, 1 marked_list, 1 footer, 2 footnotes, 228.6ms
# Speed: 10.2ms preprocess, 228.6ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 6 paragraphs, 1 marked_list, 1 header, 233.9ms
# Speed: 10.4ms preprocess, 233.9ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 table, 1 header, 255.8ms
# Speed: 22.0ms preprocess, 255.8ms inference, 7.5ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 3 paragraphs, 1 table, 1 numbered_list, 237.5ms
# Speed: 17.5ms preprocess, 237.5ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 header, 232.0ms
# Speed: 7.0ms preprocess, 232.0ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 header, 1 footnote, 233.5ms
# Speed: 7.0ms preprocess, 233.5ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 2 paragraphs, 1 numbered_list, 1 header, 252.1ms
# Speed: 9.4ms preprocess, 252.1ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 6 paragraphs, 1 picture, 1 header, 249.9ms
# Speed: 7.0ms preprocess, 249.9ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 5 paragraphs, 1 picture, 2 marked_lists, 272.2ms
# Speed: 8.0ms preprocess, 272.2ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 header, 249.9ms
# Speed: 7.0ms preprocess, 249.9ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 header, 253.7ms
# Speed: 7.0ms preprocess, 253.7ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 3 paragraphs, 1 table, 1 marked_list, 1 header, 237.1ms
# Speed: 9.0ms preprocess, 237.1ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 title, 2 paragraphs, 1 picture, 306.3ms
# Speed: 10.0ms preprocess, 306.3ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 table, 1 header, 275.6ms
# Speed: 9.0ms preprocess, 275.6ms inference, 1.4ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 picture, 1 marked_list, 1 header, 233.7ms
# Speed: 7.0ms preprocess, 233.7ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 numbered_list, 1 header, 269.3ms
# Speed: 8.0ms preprocess, 269.3ms inference, 2.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 table, 1 numbered_list, 1 header, 251.3ms
# Speed: 6.0ms preprocess, 251.3ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 table, 1 header, 260.5ms
# Speed: 8.0ms preprocess, 260.5ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 3 paragraphs, 1 table, 2 numbered_lists, 1 header, 235.1ms
# Speed: 7.0ms preprocess, 235.1ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 table, 1 picture, 1 numbered_list, 2 marked_lists, 1 header, 235.7ms
# Speed: 7.0ms preprocess, 235.7ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 5 paragraphs, 1 table, 1 numbered_list, 1 marked_list, 1 header, 289.5ms
# Speed: 12.0ms preprocess, 289.5ms inference, 2.5ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 4 paragraphs, 1 table, 240.2ms
# Speed: 8.9ms preprocess, 240.2ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x704 1 paragraph, 1 numbered_list, 1 header, 213.1ms
# Speed: 7.0ms preprocess, 213.1ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 704)
#
# 0: 768x960 2 paragraphs, 1 numbered_list, 1 marked_list, 1 header, 291.7ms
# Speed: 10.0ms preprocess, 291.7ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 paragraph, 1 picture, 1 header, 282.6ms
# Speed: 19.5ms preprocess, 282.6ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 table, 1 marked_list, 234.6ms
# Speed: 6.5ms preprocess, 234.6ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 table, 2 marked_lists, 1 header, 233.8ms
# Speed: 10.0ms preprocess, 233.8ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 table, 1 header, 240.5ms
# Speed: 8.1ms preprocess, 240.5ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 3 paragraphs, 1 table, 2 pictures, 1 marked_list, 1 header, 245.6ms
# Speed: 7.0ms preprocess, 245.6ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 table, 1 numbered_list, 1 header, 235.0ms
# Speed: 8.1ms preprocess, 235.0ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 paragraph, 1 table, 1 numbered_list, 239.2ms
# Speed: 9.0ms preprocess, 239.2ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 1 numbered_list, 2 marked_lists, 233.2ms
# Speed: 7.0ms preprocess, 233.2ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 marked_list, 235.0ms
# Speed: 7.6ms preprocess, 235.0ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 3 paragraphs, 292.6ms
# Speed: 8.0ms preprocess, 292.6ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 picture, 242.1ms
# Speed: 7.0ms preprocess, 242.1ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 2 paragraphs, 1 picture, 229.3ms
# Speed: 7.0ms preprocess, 229.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 1 picture, 236.5ms
# Speed: 8.4ms preprocess, 236.5ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 2 paragraphs, 1 picture, 238.6ms
# Speed: 7.0ms preprocess, 238.6ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 2 paragraphs, 269.3ms
# Speed: 8.0ms preprocess, 269.3ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 2 paragraphs, 237.1ms
# Speed: 8.0ms preprocess, 237.1ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 6 paragraphs, 237.2ms
# Speed: 6.5ms preprocess, 237.2ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 3 paragraphs, 1 picture, 1 numbered_list, 273.1ms
# Speed: 7.0ms preprocess, 273.1ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 titles, 1 paragraph, 235.6ms
# Speed: 7.0ms preprocess, 235.6ms inference, 2.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 3 paragraphs, 2 pictures, 1 marked_list, 239.4ms
# Speed: 8.3ms preprocess, 239.4ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 263.2ms
# Speed: 11.0ms preprocess, 263.2ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 4 paragraphs, 230.0ms
# Speed: 7.4ms preprocess, 230.0ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 3 paragraphs, 1 table, 1 picture, 1 numbered_list, 233.4ms
# Speed: 7.0ms preprocess, 233.4ms inference, 2.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 table, 1 picture, 1 marked_list, 231.6ms
# Speed: 6.2ms preprocess, 231.6ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 3 paragraphs, 2 numbered_lists, 1 marked_list, 229.8ms
# Speed: 7.3ms preprocess, 229.8ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 233.5ms
# Speed: 7.0ms preprocess, 233.5ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x704 1 title, 2 paragraphs, 1 numbered_list, 213.6ms
# Speed: 7.0ms preprocess, 213.6ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 704)
#
# 0: 768x960 3 paragraphs, 1 picture, 231.3ms
# Speed: 7.2ms preprocess, 231.3ms inference, 1.5ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 3 paragraphs, 1 picture, 1 marked_list, 275.6ms
# Speed: 9.0ms preprocess, 275.6ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 1 marked_list, 226.6ms
# Speed: 6.3ms preprocess, 226.6ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 2 marked_lists, 226.6ms
# Speed: 7.0ms preprocess, 226.6ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 4 paragraphs, 2 footnotes, 228.6ms
# Speed: 7.5ms preprocess, 228.6ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 3 paragraphs, 1 numbered_list, 1 marked_list, 228.2ms
# Speed: 8.1ms preprocess, 228.2ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 7 paragraphs, 2 marked_lists, 240.2ms
# Speed: 6.0ms preprocess, 240.2ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 marked_list, 227.1ms
# Speed: 9.0ms preprocess, 227.1ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 picture, 1 numbered_list, 261.2ms
# Speed: 11.5ms preprocess, 261.2ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 paragraph, 236.5ms
# Speed: 6.4ms preprocess, 236.5ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 3 paragraphs, 2 pictures, 256.9ms
# Speed: 6.0ms preprocess, 256.9ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 paragraph, 245.3ms
# Speed: 10.5ms preprocess, 245.3ms inference, 2.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 paragraph, 1 picture, 1 numbered_list, 1 marked_list, 242.6ms
# Speed: 7.9ms preprocess, 242.6ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 4 paragraphs, 1 picture, 244.2ms
# Speed: 7.9ms preprocess, 244.2ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 table, 1 picture, 231.2ms
# Speed: 8.0ms preprocess, 231.2ms inference, 3.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 table, 1 numbered_list, 314.1ms
# Speed: 9.0ms preprocess, 314.1ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 3 paragraphs, 1 table, 240.0ms
# Speed: 11.0ms preprocess, 240.0ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 263.5ms
# Speed: 9.0ms preprocess, 263.5ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 2 paragraphs, 1 table, 267.6ms
# Speed: 7.6ms preprocess, 267.6ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 title, 4 paragraphs, 2 pictures, 267.6ms
# Speed: 8.5ms preprocess, 267.6ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 numbered_list, 265.4ms
# Speed: 8.0ms preprocess, 265.4ms inference, 2.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 4 paragraphs, 1 picture, 1 numbered_list, 1 marked_list, 246.1ms
# Speed: 14.3ms preprocess, 246.1ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 2 paragraphs, 1 table, 1 picture, 236.6ms
# Speed: 5.9ms preprocess, 236.6ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 224.6ms
# Speed: 7.1ms preprocess, 224.6ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 4 paragraphs, 1 picture, 2 marked_lists, 226.4ms
# Speed: 10.0ms preprocess, 226.4ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 table, 1 picture, 1 numbered_list, 229.1ms
# Speed: 6.9ms preprocess, 229.1ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 picture, 1 footnote, 232.2ms
# Speed: 7.0ms preprocess, 232.2ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x704 1 title, 1 numbered_list, 210.2ms
# Speed: 7.0ms preprocess, 210.2ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 704)
#
# 0: 960x768 4 paragraphs, 1 table, 1 numbered_list, 1 marked_list, 242.7ms
# Speed: 9.0ms preprocess, 242.7ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 250.3ms
# Speed: 9.0ms preprocess, 250.3ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 3 paragraphs, 1 picture, 228.8ms
# Speed: 7.5ms preprocess, 228.8ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 numbered_list, 2 footnotes, 229.1ms
# Speed: 7.0ms preprocess, 229.1ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 3 paragraphs, 1 picture, 224.6ms
# Speed: 7.5ms preprocess, 224.6ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 table, 1 formula, 228.2ms
# Speed: 6.4ms preprocess, 228.2ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 paragraph, 1 table, 235.7ms
# Speed: 8.0ms preprocess, 235.7ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 4 paragraphs, 1 marked_list, 227.8ms
# Speed: 9.0ms preprocess, 227.8ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 4 paragraphs, 1 picture, 3 marked_lists, 232.2ms
# Speed: 7.0ms preprocess, 232.2ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 table, 235.6ms
# Speed: 8.0ms preprocess, 235.6ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 table, 1 marked_list, 232.2ms
# Speed: 8.0ms preprocess, 232.2ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 3 paragraphs, 234.7ms
# Speed: 7.0ms preprocess, 234.7ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 6 paragraphs, 1 picture, 1 numbered_list, 275.8ms
# Speed: 7.0ms preprocess, 275.8ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 3 paragraphs, 1 marked_list, 270.6ms
# Speed: 9.0ms preprocess, 270.6ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 4 paragraphs, 1 table, 285.8ms
# Speed: 10.0ms preprocess, 285.8ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 table, 286.1ms
# Speed: 31.9ms preprocess, 286.1ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 3 paragraphs, 1 picture, 1 marked_list, 232.3ms
# Speed: 7.5ms preprocess, 232.3ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 picture, 1 numbered_list, 272.9ms
# Speed: 10.0ms preprocess, 272.9ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 6 paragraphs, 237.0ms
# Speed: 8.5ms preprocess, 237.0ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 3 paragraphs, 1 table, 244.9ms
# Speed: 9.3ms preprocess, 244.9ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 3 paragraphs, 2 marked_lists, 250.1ms
# Speed: 11.0ms preprocess, 250.1ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 6 paragraphs, 1 picture, 275.6ms
# Speed: 8.0ms preprocess, 275.6ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 3 paragraphs, 2 numbered_lists, 260.4ms
# Speed: 11.0ms preprocess, 260.4ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 paragraph, 1 picture, 269.0ms
# Speed: 11.0ms preprocess, 269.0ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x704 2 paragraphs, 1 numbered_list, 231.2ms
# Speed: 7.0ms preprocess, 231.2ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 704)
#
# 0: 960x768 7 paragraphs, 1 picture, 272.9ms
# Speed: 7.0ms preprocess, 272.9ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 numbered_list, 276.6ms
# Speed: 8.5ms preprocess, 276.6ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 5 paragraphs, 1 table, 273.5ms
# Speed: 7.0ms preprocess, 273.5ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 4 paragraphs, 1 table, 1 picture, 254.6ms
# Speed: 8.0ms preprocess, 254.6ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 table, 254.2ms
# Speed: 7.2ms preprocess, 254.2ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 4 paragraphs, 1 table, 2 numbered_lists, 257.1ms
# Speed: 7.0ms preprocess, 257.1ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 table, 272.4ms
# Speed: 8.0ms preprocess, 272.4ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 2 paragraphs, 1 table, 1 header, 244.9ms
# Speed: 6.2ms preprocess, 244.9ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 paragraph, 2 tables, 1 header, 261.3ms
# Speed: 10.9ms preprocess, 261.3ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 table, 1 picture, 1 marked_list, 1 header, 1 footer, 270.5ms
# Speed: 7.4ms preprocess, 270.5ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 table, 1 numbered_list, 1 header, 1 footer, 271.8ms
# Speed: 8.0ms preprocess, 271.8ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 4 paragraphs, 1 picture, 1 marked_list, 1 header, 1 footer, 325.9ms
# Speed: 10.0ms preprocess, 325.9ms inference, 2.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 table, 1 numbered_list, 1 header, 1 footer, 267.1ms
# Speed: 8.9ms preprocess, 267.1ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 header, 2 footnotes, 270.3ms
# Speed: 7.4ms preprocess, 270.3ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 3 paragraphs, 1 picture, 1 header, 1 footer, 278.8ms
# Speed: 8.0ms preprocess, 278.8ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 picture, 1 header, 1 footer, 245.1ms
# Speed: 9.0ms preprocess, 245.1ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 title, 1 paragraph, 1 marked_list, 1 header, 236.0ms
# Speed: 15.5ms preprocess, 236.0ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 1 table, 1 header, 231.6ms
# Speed: 12.9ms preprocess, 231.6ms inference, 2.5ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 1 numbered_list, 1 header, 229.7ms
# Speed: 7.3ms preprocess, 229.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 picture, 1 numbered_list, 1 marked_list, 1 header, 1 footer, 219.7ms
# Speed: 15.6ms preprocess, 219.7ms inference, 15.6ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 1 table, 2 marked_lists, 1 header, 235.4ms
# Speed: 0.0ms preprocess, 235.4ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 2 tables, 1 header, 235.3ms
# Speed: 0.0ms preprocess, 235.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 4 paragraphs, 1 table, 1 picture, 1 header, 228.2ms
# Speed: 15.6ms preprocess, 228.2ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 1 marked_list, 1 header, 251.3ms
# Speed: 15.6ms preprocess, 251.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x704 1 title, 1 numbered_list, 1 header, 1 footer, 219.7ms
# Speed: 0.0ms preprocess, 219.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 704)
#
# 0: 768x960 3 paragraphs, 1 header, 1 footer, 282.6ms
# Speed: 0.0ms preprocess, 282.6ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 5 paragraphs, 1 header, 1 footer, 1 footnote, 235.3ms
# Speed: 15.6ms preprocess, 235.3ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 title, 1 picture, 1 header, 233.1ms
# Speed: 0.0ms preprocess, 233.1ms inference, 15.6ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 1 picture, 2 numbered_lists, 1 header, 241.3ms
# ...
#
# 0: 768x960 5 paragraphs, 1 picture, 1 numbered_list, 1 marked_list, 236.2ms
# Speed: 15.6ms preprocess, 236.2ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 2 paragraphs, 267.7ms
# Speed: 15.6ms preprocess, 267.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 5 paragraphs, 1 picture, 2 numbered_lists, 2 marked_lists, 236.7ms
# Speed: 0.0ms preprocess, 236.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 6 paragraphs, 1 numbered_list, 228.7ms
# Speed: 0.0ms preprocess, 228.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 4 paragraphs, 1 picture, 2 numbered_lists, 1 marked_list, 258.3ms
# Speed: 15.6ms preprocess, 258.3ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 title, 3 paragraphs, 1 table, 2 numbered_lists, 290.6ms
# Speed: 8.1ms preprocess, 290.6ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 2 paragraphs, 1 picture, 1 numbered_list, 2 marked_lists, 255.7ms
# Speed: 3.6ms preprocess, 255.7ms inference, 8.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 3 paragraphs, 278.0ms
# Speed: 0.0ms preprocess, 278.0ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 3 paragraphs, 1 picture, 252.4ms
# Speed: 16.2ms preprocess, 252.4ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 1 paragraph, 235.3ms
# Speed: 0.0ms preprocess, 235.3ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 title, 1 paragraph, 236.7ms
# Speed: 0.0ms preprocess, 236.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 title, 1 picture, 225.6ms
# Speed: 10.5ms preprocess, 225.6ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 title, 1 paragraph, 1 table, 236.6ms
# Speed: 0.0ms preprocess, 236.6ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 4 paragraphs, 1 table, 1 picture, 1 marked_list, 235.7ms
# Speed: 0.0ms preprocess, 235.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 5 paragraphs, 1 numbered_list, 2 marked_lists, 236.8ms
# Speed: 16.1ms preprocess, 236.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 1 paragraph, 2 pictures, 220.1ms
# Speed: 16.1ms preprocess, 220.1ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 1 table, 224.5ms
# Speed: 15.7ms preprocess, 224.5ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 titles, 5 paragraphs, 1 table, 1 picture, 235.7ms
# Speed: 0.0ms preprocess, 235.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 paragraph, 1 numbered_list, 1 marked_list, 221.0ms
# Speed: 0.0ms preprocess, 221.0ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x704 1 title, 1 paragraph, 1 numbered_list, 206.1ms
# Speed: 15.6ms preprocess, 206.1ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 704)
#
# 0: 960x768 3 paragraphs, 1 table, 1 picture, 219.7ms
# Speed: 0.0ms preprocess, 219.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 1 paragraph, 1 table, 1 header, 251.6ms
# Speed: 15.6ms preprocess, 251.6ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 title, 1 paragraph, 219.6ms
# Speed: 15.6ms preprocess, 219.6ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 5 paragraphs, 1 table, 1 numbered_list, 219.7ms
# Speed: 16.0ms preprocess, 219.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 5 paragraphs, 1 table, 219.9ms
# Speed: 15.6ms preprocess, 219.9ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 3 paragraphs, 1 table, 2 marked_lists, 235.3ms
# Speed: 0.0ms preprocess, 235.3ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 marked_list, 219.6ms
# Speed: 15.6ms preprocess, 219.6ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 2 paragraphs, 1 table, 1 numbered_list, 1 header, 1 footer, 235.4ms
# Speed: 0.0ms preprocess, 235.4ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 paragraph, 1 marked_list, 1 header, 1 footer, 220.2ms
# Speed: 6.2ms preprocess, 220.2ms inference, 15.6ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 3 paragraphs, 1 table, 1 numbered_list, 1 header, 1 footer, 235.8ms
# Speed: 0.0ms preprocess, 235.8ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 paragraph, 1 marked_list, 1 header, 226.2ms
# Speed: 15.6ms preprocess, 226.2ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 picture, 1 header, 1 footer, 220.1ms
# Speed: 11.0ms preprocess, 220.1ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 marked_list, 1 header, 1 footer, 236.1ms
# Speed: 0.0ms preprocess, 236.1ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 3 paragraphs, 1 picture, 1 header, 1 footer, 235.4ms
# Speed: 0.0ms preprocess, 235.4ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 5 paragraphs, 1 picture, 3 numbered_lists, 1 marked_list, 1 header, 1 footer, 220.1ms
# Speed: 15.6ms preprocess, 220.1ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 picture, 1 header, 1 footer, 230.1ms
# Speed: 0.0ms preprocess, 230.1ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 header, 220.1ms
# Speed: 15.6ms preprocess, 220.1ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 picture, 1 header, 236.1ms
# Speed: 0.0ms preprocess, 236.1ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 6 paragraphs, 2 marked_lists, 1 header, 1 footer, 221.6ms
# Speed: 15.7ms preprocess, 221.6ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 table, 1 numbered_list, 1 header, 1 footer, 226.2ms
# Speed: 6.5ms preprocess, 226.2ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 4 paragraphs, 1 table, 2 numbered_lists, 1 marked_list, 1 header, 1 footer, 219.7ms
# Speed: 0.0ms preprocess, 219.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 3 paragraphs, 1 marked_list, 1 header, 1 footer, 219.6ms
# Speed: 15.6ms preprocess, 219.6ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 2 paragraphs, 1 table, 1 picture, 1 header, 1 footer, 235.3ms
# Speed: 0.0ms preprocess, 235.3ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 table, 1 header, 1 footer, 220.1ms
# Speed: 15.6ms preprocess, 220.1ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 table, 1 header, 1 footer, 220.1ms
# Speed: 15.7ms preprocess, 220.1ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 2 paragraphs, 1 picture, 1 header, 1 footer, 235.3ms
# Speed: 15.6ms preprocess, 235.3ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 table, 1 picture, 1 header, 219.7ms
# Speed: 2.5ms preprocess, 219.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 3 paragraphs, 1 header, 1 footer, 228.7ms
# Speed: 15.6ms preprocess, 228.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x704 2 paragraphs, 1 numbered_list, 1 header, 1 footer, 219.7ms
# Speed: 0.0ms preprocess, 219.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 704)
#
# 0: 960x768 2 paragraphs, 1 header, 1 footer, 266.9ms
# Speed: 15.6ms preprocess, 266.9ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 1 picture, 1 header, 1 footer, 251.9ms
# Speed: 15.6ms preprocess, 251.9ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 2 tables, 1 header, 1 footer, 264.0ms
# Speed: 3.0ms preprocess, 264.0ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 2 marked_lists, 1 header, 266.5ms
# Speed: 0.0ms preprocess, 266.5ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 titles, 2 paragraphs, 2 pictures, 1 header, 219.7ms
# Speed: 15.6ms preprocess, 219.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 2 paragraphs, 1 numbered_list, 1 header, 1 footer, 220.1ms
# Speed: 7.0ms preprocess, 220.1ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 4 paragraphs, 1 picture, 1 marked_list, 1 header, 1 footer, 235.3ms
# Speed: 0.0ms preprocess, 235.3ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 2 paragraphs, 1 numbered_list, 1 marked_list, 1 header, 236.1ms
# Speed: 0.0ms preprocess, 236.1ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 picture, 1 numbered_list, 1 marked_list, 1 header, 219.3ms
# Speed: 0.0ms preprocess, 219.3ms inference, 15.6ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 4 paragraphs, 1 picture, 1 numbered_list, 1 header, 250.6ms
# Speed: 0.0ms preprocess, 250.6ms inference, 16.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 paragraph, 1 header, 219.7ms
# Speed: 0.0ms preprocess, 219.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 table, 1 header, 235.9ms
# Speed: 0.0ms preprocess, 235.9ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 title, 6 paragraphs, 1 picture, 2 numbered_lists, 1 header, 220.1ms
# Speed: 16.1ms preprocess, 220.1ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 3 titles, 1 paragraph, 1 header, 220.5ms
# Speed: 0.0ms preprocess, 220.5ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 5 paragraphs, 2 pictures, 1 table_signature, 2 numbered_lists, 1 header, 235.8ms
# Speed: 15.6ms preprocess, 235.8ms inference, 15.7ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 numbered_list, 1 header, 1 footnote, 220.5ms
# Speed: 15.7ms preprocess, 220.5ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 3 paragraphs, 1 picture, 1 marked_list, 1 header, 237.3ms
# Speed: 0.0ms preprocess, 237.3ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 4 paragraphs, 2 marked_lists, 1 header, 219.7ms
# Speed: 0.0ms preprocess, 219.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 title, 4 paragraphs, 1 table, 2 numbered_lists, 1 marked_list, 1 header, 235.3ms
# Speed: 0.0ms preprocess, 235.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x704 1 paragraph, 1 numbered_list, 1 header, 234.7ms
# Speed: 0.0ms preprocess, 234.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 704)
#
# 0: 960x768 1 title, 3 paragraphs, 1 table, 1 header, 220.1ms
# Speed: 14.0ms preprocess, 220.1ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 6 paragraphs, 1 table, 220.1ms
# Speed: 15.5ms preprocess, 220.1ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 titles, 4 paragraphs, 1 picture, 1 marked_list, 251.0ms
# Speed: 0.0ms preprocess, 251.0ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 marked_list, 1 header, 1 footnote, 219.7ms
# Speed: 15.6ms preprocess, 219.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 paragraph, 1 header, 256.5ms
# Speed: 10.5ms preprocess, 256.5ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 header, 231.7ms
# Speed: 4.2ms preprocess, 231.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 2 paragraphs, 1 marked_list, 1 header, 235.3ms
# Speed: 0.0ms preprocess, 235.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 89
#      86         y_pred.extend(pred_classes)
#      88 # 2. Рассчитываем метрики
# ---> 89 precision, recall, f1, _ = precision_recall_fscore_support(y_true, y_pred, average="weighted")
#      90 mIoU = average_precision_score(y_true, y_pred)  # Оценка mAP50-95 (приближённая)
#      91 fitness = (precision + recall + f1) / 3  # Условная метрика для общего качества
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1789, in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1626 """Compute precision, recall, F-measure and support for each class.
#    1627
#    1628 The precision is the ratio ``tp / (tp + fp)`` where ``tp`` is the number of
#    (...)
#    1786  array([2, 2, 2]))
#    1787 """
#    1788 _check_zero_division(zero_division)
# -> 1789 labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1791 # Calculate tp_sum, pred_sum, true_sum ###
#    1792 samplewise = average == "samples"
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1561, in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1558 if average not in average_options and average != "binary":
#    1559     raise ValueError("average has to be one of " + str(average_options))
# -> 1561 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    1562 # Convert to Python primitive type to avoid NumPy type / Python str
#    1563 # comparison. See https://github.com/numpy/numpy/issues/6784
#    1564 present_labels = unique_labels(y_true, y_pred).tolist()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:103, in _check_targets(y_true, y_pred)
#      76 """Check that y_true and y_pred belong to the same classification task.
#      77
#      78 This converts multiclass or binary types to a common shape, and raises a
#    (...)
#     100 y_pred : array or indicator matrix
#     101 """
#     102 xp, _ = get_namespace(y_true, y_pred)
# --> 103 check_consistent_length(y_true, y_pred)
#     104 type_true = type_of_target(y_true, input_name="y_true")
#     105 type_pred = type_of_target(y_pred, input_name="y_pred")
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:457, in check_consistent_length(*arrays)
#     455 uniques = np.unique(lengths)
#     456 if len(uniques) > 1:
# --> 457     raise ValueError(
#     458         "Found input variables with inconsistent numbers of samples: %r"
#     459         % [int(l) for l in lengths]
#     460     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [6847, 5343]

# %%
import os

# Путь к тестовому набору данных
test_data_path = r"C:\\Users\\Vito\\Jupyter\\Models\\test_1_grup_Ivan"

# Проверяем существование необходимых папок
if not os.path.exists(os.path.join(test_data_path, "images")):
    raise FileNotFoundError(f"Папка с изображениями {os.path.join(test_data_path, 'images')} не найдена.")
if not os.path.exists(os.path.join(test_data_path, "labels")):
    raise FileNotFoundError(f"Папка с разметкой {os.path.join(test_data_path, 'labels')} не найдена.")

# Формируем YAML-строку с описанием тестового набора
test_data_yaml = (
    "path: " + test_data_path.replace("\\", "/") + "\n"
    "train: \"\"  # Пустой путь, так как обучение не требуется\n"
    "val: images\n"
    "names:\n"
    "  0: title\n"
    "  1: paragraph\n"
    "  2: table\n"
    "  3: picture\n"
    "  4: table_signature\n"
    "  5: picture_signature\n"
    "  6: numbered_list\n"
    "  7: marked_list\n"
    "  8: header\n"
    "  9: footer\n"
    "  10: footnote\n"
    "  11: formula\n"
)

# Сохраняем YAML-файл
yaml_path = os.path.join(test_data_path, "test.yaml")
with open(yaml_path, "w", encoding="utf-8") as file:
    file.write(test_data_yaml)

print(f"Файл YAML для тестового набора сохранён в: {yaml_path}")

# Выполняем валидацию на тестовом наборе
results = model.val(data=yaml_path)

# Получаем метрики из results_dict
metrics = results.results_dict

# Извлекаем precision и recall
precision = metrics['metrics/precision(B)']
recall = metrics['metrics/recall(B)']

# Вычисляем F1 Score
f1_score = 2 * (precision * recall) / (precision + recall)

# Извлекаем mIoU (mAP50-95)
mAP50_95 = metrics['metrics/mAP50-95(B)']

# Печатаем метрики
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1_score)
print("mIoU (mAP50-95):", mAP50_95)
print("Fitness:", metrics['fitness'])
# Out:
# Файл YAML для тестового набора сохранён в: C:\\Users\\Vito\\Jupyter\\Models\\test_1_grup_Ivan\test.yaml
# Ultralytics 8.3.34  Python-3.11.9 torch-2.5.1+cpu CPU (AMD Ryzen 7 7840HS w/ Radeon 780M Graphics)
# val: Scanning C:\Users\Vito\Jupyter\Models\test_1_grup_Ivan\labels... 1000 images, 0 backgrounds, 0 corrupt: 100%|█████
# val: New cache created: C:\Users\Vito\Jupyter\Models\test_1_grup_Ivan\labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 63/63 [06:19
#                    all       1000       6847      0.498      0.405      0.502      0.403
#                  title        444        571      0.049     0.0368    0.00893    0.00712
#              paragraph        854       2289       0.51      0.616      0.605      0.373
#                  table        338        379      0.758      0.871      0.895      0.658
#                picture        240        241      0.292      0.622      0.407      0.151
#        table_signature        251        272       0.17    0.00368      0.154       0.14
#      picture_signature        240        241      0.156    0.00415      0.104      0.088
#          numbered_list        299        341       0.88      0.754      0.825      0.774
#            marked_list        241        284       0.68      0.972      0.955      0.883
#                 header        574        574      0.997      0.606      0.988      0.908
#                 footer        691        691          1      0.361      0.869      0.677
#               footnote        212        259          0          0          0          0
#                formula        483        705      0.486    0.00942      0.209      0.182
# Speed: 1.8ms preprocess, 267.1ms inference, 0.0ms loss, 0.5ms postprocess per image
# Results saved to runs\detect\val
# Precision: 0.4981986839171249
# Recall: 0.40465170867542105
# F1 Score: 0.44657885816059184
# mIoU (mAP50-95): 0.40336582494324175
# Fitness: 0.4131901882332051

# %% [markdown]
# Обработка test_1_grup_Tim

# %%
import os

# Пути к папкам
png_dir = "C:\\Users\\Vito\\Jupyter\\Models\\test_1_grup_Tim\\image"  # Папка с PNG
json_dir = "C:\\Users\\Vito\\Jupyter\\Models\\test_1_grup_Tim\\json"  # Папка с JSON

# Получаем базовые имена файлов (без расширений)
png_files = {os.path.splitext(f)[0] for f in os.listdir(png_dir) if f.endswith(".png")}
json_files = {os.path.splitext(f)[0] for f in os.listdir(json_dir) if f.endswith(".json")}

# Выявляем лишние файлы
extra_png_files = png_files - json_files  # PNG, которых нет в JSON
extra_json_files = json_files - png_files  # JSON, которых нет в PNG

# Вывод результата
print(f"Лишние PNG файлы ({len(extra_png_files)}):", extra_png_files)
print(f"Лишние JSON файлы ({len(extra_json_files)}):", extra_json_files)

# Записать результат в файлы для анализа
with open("extra_png_files.txt", "w") as f:
    f.write("\n".join(sorted(extra_png_files)))

with open("extra_json_files.txt", "w") as f:
    f.write("\n".join(sorted(extra_json_files)))

print("Проверка завершена. Результаты записаны в extra_png_files.txt и extra_json_files.txt.")
# Out:
# Лишние PNG файлы (16): {'document_70_page_3_annotated', 'document_70_page_4_annotated', 'document_71_page_6_annotated', 'document_71_page_3_annotated', 'document_70_page_1_annotated', 'document_70_page_8_annotated', 'document_71_page_5_annotated', 'document_71_page_4_annotated', 'document_70_page_7_annotated', 'document_70_page_5_annotated', 'document_71_page_2_annotated', 'document_70_page_2_annotated', 'document_70_page_9_annotated', 'document_70_page_10_annotated', 'document_71_page_1_annotated', 'document_70_page_6_annotated'}
# Лишние JSON файлы (16): {'document_71_page_1', 'document_71_page_4', 'document_71_page_2', 'document_70_page_5', 'document_70_page_8', 'document_71_page_3', 'document_70_page_4', 'document_71_page_5', 'document_70_page_2', 'document_70_page_10', 'document_71_page_6', 'document_70_page_3', 'document_70_page_9', 'document_70_page_7', 'document_70_page_6', 'document_70_page_1'}
# Проверка завершена. Результаты записаны в extra_png_files.txt и extra_json_files.txt.

# %%
import os

# Пути к папкам
png_dir = "C:\\Users\\Vito\\Jupyter\\Models\\test_1_grup_Tim\\image"  # Папка с PNG
json_dir = "C:\\Users\\Vito\\Jupyter\\Models\\test_1_grup_Tim\\json"  # Папка с JSON

# Файлы с лишними элементами
extra_png_file = "extra_png_files.txt"
extra_json_file = "extra_json_files.txt"

# Функция удаления файлов
def delete_files(file_list, folder_path):
    with open(file_list, "r") as f:
        files_to_delete = f.read().splitlines()
    
    for file_name in files_to_delete:
        file_path = os.path.join(folder_path, f"{file_name}.png") if "png" in file_list else os.path.join(folder_path, f"{file_name}.json")
        if os.path.exists(file_path):
            os.remove(file_path)
            print(f"Удалено: {file_path}")
        else:
            print(f"Файл не найден (пропущено): {file_path}")

# Удаляем лишние PNG файлы
delete_files(extra_png_file, png_dir)

# Удаляем лишние JSON файлы
delete_files(extra_json_file, json_dir)

print("Удаление завершено.")
# Out:
# Удалено: C:\Users\Vito\Jupyter\Models\test_1_grup_Tim\image\document_70_page_10_annotated.png
# Удалено: C:\Users\Vito\Jupyter\Models\test_1_grup_Tim\image\document_70_page_1_annotated.png
# Удалено: C:\Users\Vito\Jupyter\Models\test_1_grup_Tim\image\document_70_page_2_annotated.png
# Удалено: C:\Users\Vito\Jupyter\Models\test_1_grup_Tim\image\document_70_page_3_annotated.png
# Удалено: C:\Users\Vito\Jupyter\Models\test_1_grup_Tim\image\document_70_page_4_annotated.png
# Удалено: C:\Users\Vito\Jupyter\Models\test_1_grup_Tim\image\document_70_page_5_annotated.png
# Удалено: C:\Users\Vito\Jupyter\Models\test_1_grup_Tim\image\document_70_page_6_annotated.png
# Удалено: C:\Users\Vito\Jupyter\Models\test_1_grup_Tim\image\document_70_page_7_annotated.png
# Удалено: C:\Users\Vito\Jupyter\Models\test_1_grup_Tim\image\document_70_page_8_annotated.png
# Удалено: C:\Users\Vito\Jupyter\Models\test_1_grup_Tim\image\document_70_page_9_annotated.png
# Удалено: C:\Users\Vito\Jupyter\Models\test_1_grup_Tim\image\document_71_page_1_annotated.png
# Удалено: C:\Users\Vito\Jupyter\Models\test_1_grup_Tim\image\document_71_page_2_annotated.png
# Удалено: C:\Users\Vito\Jupyter\Models\test_1_grup_Tim\image\document_71_page_3_annotated.png
# Удалено: C:\Users\Vito\Jupyter\Models\test_1_grup_Tim\image\document_71_page_4_annotated.png
# Удалено: C:\Users\Vito\Jupyter\Models\test_1_grup_Tim\image\document_71_page_5_annotated.png
# Удалено: C:\Users\Vito\Jupyter\Models\test_1_grup_Tim\image\document_71_page_6_annotated.png
# Удалено: C:\Users\Vito\Jupyter\Models\test_1_grup_Tim\json\document_70_page_1.json
# Удалено: C:\Users\Vito\Jupyter\Models\test_1_grup_Tim\json\document_70_page_10.json
# Удалено: C:\Users\Vito\Jupyter\Models\test_1_grup_Tim\json\document_70_page_2.json
# Удалено: C:\Users\Vito\Jupyter\Models\test_1_grup_Tim\json\document_70_page_3.json
# Удалено: C:\Users\Vito\Jupyter\Models\test_1_grup_Tim\json\document_70_page_4.json
# Удалено: C:\Users\Vito\Jupyter\Models\test_1_grup_Tim\json\document_70_page_5.json
# Удалено: C:\Users\Vito\Jupyter\Models\test_1_grup_Tim\json\document_70_page_6.json
# Удалено: C:\Users\Vito\Jupyter\Models\test_1_grup_Tim\json\document_70_page_7.json
# Удалено: C:\Users\Vito\Jupyter\Models\test_1_grup_Tim\json\document_70_page_8.json
# Удалено: C:\Users\Vito\Jupyter\Models\test_1_grup_Tim\json\document_70_page_9.json
# Удалено: C:\Users\Vito\Jupyter\Models\test_1_grup_Tim\json\document_71_page_1.json
# Удалено: C:\Users\Vito\Jupyter\Models\test_1_grup_Tim\json\document_71_page_2.json
# Удалено: C:\Users\Vito\Jupyter\Models\test_1_grup_Tim\json\document_71_page_3.json
# Удалено: C:\Users\Vito\Jupyter\Models\test_1_grup_Tim\json\document_71_page_4.json
# Удалено: C:\Users\Vito\Jupyter\Models\test_1_grup_Tim\json\document_71_page_5.json
# Удалено: C:\Users\Vito\Jupyter\Models\test_1_grup_Tim\json\document_71_page_6.json
# Удаление завершено.

# %%
# Предобработка данных
import os
import json

# Папки
json_dir = "C:\\Users\\Vito\\Jupyter\\Models\\test_1_grup_Tim\\json"  # Путь к папке с JSON
images_dir = "C:\\Users\\Vito\\Jupyter\\Models\\test_1_grup_Tim\\image"    # Путь к изображениям
output_dir = "C:\\Users\\Vito\\Jupyter\\Models\\test_1_grup_Tim\\labels"  # Папка для сохранения YOLO разметки

# Словарь классов
class_mapping = {
    "title": 0,
    "paragraph": 1,
    "table": 2,
    "picture": 3,
    "graph": 3,
    "table_signature": 4,
    "picture_signature": 5,
    "numbered_list": 6,
    "marked_list": 7,
    "header": 8,
    "footer": 9,
    "footnote": 10,
    "formula": 11
}

# Создаем выходную папку
os.makedirs(output_dir, exist_ok=True)

# Функция для нормализации координат
def normalize_bbox(bbox, img_width, img_height):
    x1, y1, x2, y2 = bbox
    x_center = (x1 + x2) / 2 / img_width
    y_center = (y1 + y2) / 2 / img_height
    width = (x2 - x1) / img_width
    height = (y2 - y1) / img_height
    return x_center, y_center, width, height

# Проход по JSON файлам
for json_file in os.listdir(json_dir):
    if json_file.endswith(".json"):
        # Открываем JSON файл
        with open(os.path.join(json_dir, json_file), "r") as f:
            data = json.load(f)
        
        img_width = data["image_width"]
        img_height = data["image_height"]
        txt_filename = os.path.splitext(json_file)[0] + ".txt"
        txt_path = os.path.join(output_dir, txt_filename)
        
        # Запись данных в YOLO формат
        with open(txt_path, "w") as txt_file:
            for class_name, bboxes in data.items():
                if class_name in class_mapping:
                    class_id = class_mapping[class_name]
                    for bbox in bboxes:
                        x_center, y_center, width, height = normalize_bbox(bbox, img_width, img_height)
                        txt_file.write(f"{class_id} {x_center} {y_center} {width} {height}\n")

# %%
import os
import cv2
from ultralytics import YOLO
from PIL import Image
from pathlib import Path
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import average_precision_score
import numpy as np

# Пути
input_images_dir = "C:\\Users\\Vito\\Jupyter\\Models\\test_1_grup_Tim\\image"  # Папка с изображениями документов
labels_dir = "C:\\Users\\Vito\\Jupyter\\Models\\test_1_grup_Tim\\labels"  # Папка с разметкой YOLO
output_images_dir = "C:\\Users\\Vito\\Jupyter\\Models\\test_1_grup_Tim\\test_results"  # Папка для аннотированных изображений

# Создаём папку для аннотированных изображений, если она не существует
os.makedirs(output_images_dir, exist_ok=True)

# Загружаем модель YOLO
model = YOLO("C:\\Users\\Vito\\Jupyter\\Models\\runs YOLO11s datasetv3 aug imgsz=960\\detect\\train\\weights\\best.pt")

# Настройка кастомных порогов для каждого класса
custom_confidences = {
    0: 0.3,  # title
    1: 0.1,  # paragraph
    9: 0.15, # footer
    11: 0.1, # formula
    10: 0.88, # footnote
    6: 0.4, # numbered_list
    7: 0.4  # marked_list
}

# Список всех изображений в папке
image_files = [f for f in os.listdir(input_images_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
image_files.sort()  # Сортируем для упорядоченности

# 1. Обрабатываем изображения моделью YOLO и визуализируем предсказания с кастомными порогами
annotated_images = []
y_true, y_pred = [], []  # Для метрик

for image_file in image_files:
    image_path = os.path.join(input_images_dir, image_file)
    label_path = os.path.join(labels_dir, Path(image_file).stem + ".txt")  # Соответствующий файл разметки
    
    img = cv2.imread(image_path)

    # Применяем модель YOLO
    results = model.predict(source=img, conf=0.4, iou=0.51, save=False)
    
    # Фильтруем предсказания на основе кастомных порогов для классов
    filtered_boxes = []
    for result in results:
        for box in result.boxes:
            cls = int(box.cls)  # Класс объекта
            conf = float(box.conf)  # Уверенность объекта

            # Проверяем, превышает ли уверенность кастомный порог для данного класса
            if cls in custom_confidences:
                if conf >= custom_confidences[cls]:
                    filtered_boxes.append(box)
            else:
                # Используем общий порог (например, 0.4) для классов, для которых не задан кастомный порог
                if conf >= 0.4:
                    filtered_boxes.append(box)

        # Применяем отфильтрованные боксы для визуализации
        result.boxes = filtered_boxes

    # Наносим рамки на изображение
    annotated_img = results[0].plot()  # Визуализируем предсказания (аннотированное изображение)
    annotated_image_path = os.path.join(output_images_dir, image_file)
    cv2.imwrite(annotated_image_path, annotated_img)
    annotated_images.append(annotated_image_path)

    # Сравниваем с разметкой для метрик
    if os.path.exists(label_path):
        # Чтение разметки (ground truth)
        with open(label_path, "r") as f:
            true_boxes = [line.strip().split() for line in f.readlines()]
            true_classes = [int(box[0]) for box in true_boxes]  # Классы из разметки

        # Собираем предсказания
        pred_classes = [int(box.cls) for box in filtered_boxes]

        # Добавляем в список для метрик
        y_true.extend(true_classes)
        y_pred.extend(pred_classes)

# 2. Рассчитываем метрики
precision, recall, f1, _ = precision_recall_fscore_support(y_true, y_pred, average="weighted")
mIoU = average_precision_score(y_true, y_pred)  # Оценка mAP50-95 (приближённая)
fitness = (precision + recall + f1) / 3  # Условная метрика для общего качества

# Вывод метрик
print(f"Precision: {precision:.6f}")
print(f"Recall: {recall:.6f}")
print(f"F1 Score: {f1:.6f}")
print(f"mIoU (mAP50-95): {mIoU:.6f}")
print(f"Fitness: {fitness:.6f}")
# Out:
# 0: 768x960 1 title, 1 paragraph, 1 numbered_list, 1 header, 1 footer, 486.7ms
# Speed: 13.0ms preprocess, 486.7ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 header, 1 footer, 430.8ms
# Speed: 20.5ms preprocess, 430.8ms inference, 3.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 table, 1 header, 1 footer, 393.5ms
# Speed: 16.0ms preprocess, 393.5ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 4 paragraphs, 1 numbered_list, 1 header, 1 footer, 2 footnotes, 298.8ms
# Speed: 13.0ms preprocess, 298.8ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 header, 1 footer, 236.3ms
# Speed: 7.1ms preprocess, 236.3ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 titles, 4 paragraphs, 2 pictures, 1 header, 1 footer, 327.0ms
# Speed: 14.6ms preprocess, 327.0ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 header, 1 footer, 275.8ms
# Speed: 9.0ms preprocess, 275.8ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 header, 1 footer, 238.7ms
# Speed: 7.3ms preprocess, 238.7ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 table, 1 header, 1 footer, 236.6ms
# Speed: 8.1ms preprocess, 236.6ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 header, 1 footer, 232.7ms
# Speed: 8.1ms preprocess, 232.7ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 paragraph, 1 header, 1 footer, 240.3ms
# Speed: 8.0ms preprocess, 240.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 titles, 1 paragraph, 3 pictures, 1 numbered_list, 1 header, 1 footer, 237.7ms
# Speed: 15.6ms preprocess, 237.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 table, 1 picture, 1 header, 1 footer, 2 footnotes, 253.9ms
# Speed: 10.6ms preprocess, 253.9ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 header, 1 footer, 234.8ms
# Speed: 0.0ms preprocess, 234.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 title, 1 paragraph, 1 picture, 1 numbered_list, 1 header, 1 footer, 224.2ms
# Speed: 15.6ms preprocess, 224.2ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 4 paragraphs, 3 pictures, 1 header, 1 footer, 236.9ms
# Speed: 0.0ms preprocess, 236.9ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 2 titles, 1 paragraph, 1 picture, 1 header, 242.5ms
# Speed: 0.0ms preprocess, 242.5ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 picture, 1 header, 1 footnote, 241.6ms
# Speed: 0.0ms preprocess, 241.6ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 1 table, 1 header, 283.6ms
# Speed: 10.5ms preprocess, 283.6ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 2 pictures, 1 header, 235.8ms
# Speed: 0.0ms preprocess, 235.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 numbered_list, 1 marked_list, 1 header, 263.6ms
# Speed: 0.0ms preprocess, 263.6ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 numbered_list, 1 header, 235.3ms
# Speed: 13.1ms preprocess, 235.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 numbered_list, 1 header, 234.7ms
# Speed: 0.0ms preprocess, 234.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 1 paragraph, 1 header, 213.7ms
# Speed: 6.6ms preprocess, 213.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 3 paragraphs, 1 numbered_list, 1 header, 1 footer, 235.5ms
# Speed: 0.0ms preprocess, 235.5ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 paragraph, 1 numbered_list, 1 header, 234.8ms
# Speed: 0.0ms preprocess, 234.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 1 paragraph, 1 header, 214.6ms
# Speed: 5.5ms preprocess, 214.6ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 title, 1 paragraph, 1 table, 1 picture, 1 header, 1 footer, 219.7ms
# Speed: 15.6ms preprocess, 219.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 picture, 1 header, 1 footer, 250.5ms
# Speed: 0.0ms preprocess, 250.5ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 header, 1 footer, 1 footnote, 234.7ms
# Speed: 0.0ms preprocess, 234.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 header, 1 footer, 235.2ms
# Speed: 15.7ms preprocess, 235.2ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 2 paragraphs, 1 header, 1 footer, 219.4ms
# Speed: 15.6ms preprocess, 219.4ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 header, 1 footer, 236.4ms
# Speed: 0.0ms preprocess, 236.4ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 pictures, 1 header, 1 footer, 235.0ms
# Speed: 0.0ms preprocess, 235.0ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 1 paragraph, 1 numbered_list, 1 header, 1 footer, 251.2ms
# Speed: 0.0ms preprocess, 251.2ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 table, 1 header, 1 footer, 332.5ms
# Speed: 15.6ms preprocess, 332.5ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 numbered_list, 1 header, 1 footer, 235.3ms
# Speed: 0.0ms preprocess, 235.3ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 header, 1 footer, 1 footnote, 241.3ms
# Speed: 0.0ms preprocess, 241.3ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 2 pictures, 1 header, 1 footer, 284.0ms
# Speed: 0.0ms preprocess, 284.0ms inference, 1.1ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 1 paragraph, 1 table, 1 header, 1 footer, 1 footnote, 235.6ms
# Speed: 0.0ms preprocess, 235.6ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 header, 1 footer, 235.3ms
# Speed: 15.7ms preprocess, 235.3ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 2 titles, 2 paragraphs, 1 table, 3 pictures, 1 header, 1 footer, 1 footnote, 235.1ms
# Speed: 0.0ms preprocess, 235.1ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 picture, 1 header, 1 footer, 267.9ms
# Speed: 0.0ms preprocess, 267.9ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 table, 1 marked_list, 1 header, 1 footer, 2 footnotes, 246.3ms
# Speed: 20.7ms preprocess, 246.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 header, 1 footer, 235.7ms
# Speed: 0.0ms preprocess, 235.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 title, 3 paragraphs, 1 numbered_list, 1 header, 1 footer, 263.2ms
# Speed: 9.7ms preprocess, 263.2ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 4 paragraphs, 1 numbered_list, 1 marked_list, 1 header, 1 footer, 315.7ms
# Speed: 18.8ms preprocess, 315.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 3 paragraphs, 1 header, 1 footer, 247.8ms
# Speed: 14.4ms preprocess, 247.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 header, 1 footer, 233.3ms
# Speed: 15.6ms preprocess, 233.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 3 paragraphs, 1 header, 1 footer, 234.4ms
# Speed: 8.1ms preprocess, 234.4ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 header, 1 footer, 272.0ms
# Speed: 23.8ms preprocess, 272.0ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 3 paragraphs, 2 tables, 1 header, 1 footer, 215.2ms
# Speed: 12.9ms preprocess, 215.2ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 marked_list, 1 header, 1 footer, 1 footnote, 233.8ms
# Speed: 7.2ms preprocess, 233.8ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 numbered_list, 1 header, 1 footer, 213.3ms
# Speed: 8.1ms preprocess, 213.3ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 picture, 1 header, 1 footer, 231.7ms
# Speed: 11.3ms preprocess, 231.7ms inference, 1.6ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 header, 1 footer, 231.4ms
# Speed: 6.0ms preprocess, 231.4ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 marked_list, 1 header, 1 footer, 230.8ms
# Speed: 7.0ms preprocess, 230.8ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 3 paragraphs, 1 numbered_list, 1 header, 1 footer, 235.1ms
# Speed: 9.0ms preprocess, 235.1ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 marked_list, 1 header, 1 footer, 256.0ms
# Speed: 10.1ms preprocess, 256.0ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 2 paragraphs, 1 header, 1 footer, 236.6ms
# Speed: 10.0ms preprocess, 236.6ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 marked_list, 1 header, 1 footer, 251.6ms
# Speed: 10.0ms preprocess, 251.6ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 title, 2 paragraphs, 1 table, 1 marked_list, 1 header, 1 footer, 240.0ms
# Speed: 14.6ms preprocess, 240.0ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 picture, 1 header, 1 footer, 234.6ms
# Speed: 6.6ms preprocess, 234.6ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 2 titles, 1 paragraph, 1 picture, 1 footer, 231.1ms
# Speed: 6.0ms preprocess, 231.1ms inference, 0.5ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 table, 1 footer, 234.3ms
# Speed: 7.0ms preprocess, 234.3ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 footer, 237.0ms
# Speed: 8.0ms preprocess, 237.0ms inference, 2.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 1 numbered_list, 230.9ms
# Speed: 8.0ms preprocess, 230.9ms inference, 2.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 5 paragraphs, 1 picture, 269.0ms
# Speed: 8.0ms preprocess, 269.0ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 2 paragraphs, 2 pictures, 1 footer, 258.4ms
# Speed: 8.0ms preprocess, 258.4ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 footer, 268.0ms
# Speed: 7.0ms preprocess, 268.0ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 3 paragraphs, 1 header, 1 footer, 230.6ms
# Speed: 7.0ms preprocess, 230.6ms inference, 11.5ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 paragraph, 1 header, 1 footer, 281.8ms
# Speed: 0.0ms preprocess, 281.8ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 paragraph, 1 header, 1 footer, 2 footnotes, 235.8ms
# Speed: 0.0ms preprocess, 235.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 header, 1 footer, 1 footnote, 267.3ms
# Speed: 0.0ms preprocess, 267.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 marked_list, 1 header, 1 footer, 220.1ms
# Speed: 15.6ms preprocess, 220.1ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 header, 1 footer, 254.7ms
# Speed: 0.0ms preprocess, 254.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 3 paragraphs, 2 pictures, 1 header, 1 footer, 252.9ms
# Speed: 15.6ms preprocess, 252.9ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 3 pictures, 1 header, 1 footer, 240.8ms
# Speed: 0.0ms preprocess, 240.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 table, 1 numbered_list, 1 header, 1 footer, 1 footnote, 235.7ms
# Speed: 0.0ms preprocess, 235.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 header, 1 footer, 217.5ms
# Speed: 6.5ms preprocess, 217.5ms inference, 7.5ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 header, 1 footer, 220.6ms
# Speed: 3.5ms preprocess, 220.6ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 header, 1 footer, 219.3ms
# Speed: 15.6ms preprocess, 219.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 header, 1 footer, 1 footnote, 224.2ms
# Speed: 9.5ms preprocess, 224.2ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 header, 1 footer, 267.4ms
# Speed: 0.0ms preprocess, 267.4ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 header, 1 footer, 1 footnote, 226.9ms
# Speed: 11.4ms preprocess, 226.9ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 header, 1 footer, 235.4ms
# Speed: 0.0ms preprocess, 235.4ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 paragraph, 1 picture, 2 headers, 1 footer, 235.7ms
# Speed: 0.0ms preprocess, 235.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 5 paragraphs, 1 picture, 1 marked_list, 1 header, 1 footer, 235.3ms
# Speed: 0.0ms preprocess, 235.3ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 3 paragraphs, 1 table, 3 pictures, 1 numbered_list, 1 header, 1 footer, 235.8ms
# Speed: 0.0ms preprocess, 235.8ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 1 picture, 1 numbered_list, 1 header, 1 footer, 251.3ms
# Speed: 0.0ms preprocess, 251.3ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 3 paragraphs, 2 pictures, 1 header, 1 footer, 219.9ms
# Speed: 0.0ms preprocess, 219.9ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 header, 1 footer, 266.9ms
# Speed: 15.6ms preprocess, 266.9ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 paragraph, 1 numbered_list, 1 header, 1 footer, 267.7ms
# Speed: 15.6ms preprocess, 267.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 3 paragraphs, 1 table, 1 header, 1 footer, 283.0ms
# Speed: 15.6ms preprocess, 283.0ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 title, 1 table, 1 picture, 1 header, 1 footer, 1 footnote, 251.3ms
# Speed: 15.6ms preprocess, 251.3ms inference, 15.6ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 header, 1 footer, 1 footnote, 236.3ms
# Speed: 0.0ms preprocess, 236.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 2 pictures, 1 header, 1 footer, 213.0ms
# Speed: 7.5ms preprocess, 213.0ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 title, 1 header, 1 footer, 238.4ms
# Speed: 0.0ms preprocess, 238.4ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 header, 1 footer, 1 footnote, 283.0ms
# Speed: 6.5ms preprocess, 283.0ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 2 paragraphs, 1 header, 1 footer, 236.3ms
# Speed: 15.6ms preprocess, 236.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 2 paragraphs, 2 marked_lists, 1 header, 236.2ms
# Speed: 0.0ms preprocess, 236.2ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 5 paragraphs, 1 picture, 1 header, 235.8ms
# Speed: 0.0ms preprocess, 235.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 301.0ms
# Speed: 15.6ms preprocess, 301.0ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 228.7ms
# Speed: 0.0ms preprocess, 228.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 1 paragraph, 1 picture, 1 numbered_list, 1 marked_list, 1 header, 1 footnote, 232.4ms
# Speed: 15.6ms preprocess, 232.4ms inference, 1.1ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 header, 220.5ms
# Speed: 9.2ms preprocess, 220.5ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 table, 1 header, 226.3ms
# Speed: 9.7ms preprocess, 226.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 header, 236.2ms
# Speed: 8.0ms preprocess, 236.2ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 3 paragraphs, 2 pictures, 1 numbered_list, 1 marked_list, 1 footer, 224.6ms
# Speed: 15.6ms preprocess, 224.6ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 paragraph, 1 numbered_list, 1 footer, 345.9ms
# Speed: 15.6ms preprocess, 345.9ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 paragraph, 1 footer, 231.7ms
# Speed: 0.0ms preprocess, 231.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 3 paragraphs, 1 footer, 220.1ms
# Speed: 15.6ms preprocess, 220.1ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 1 footer, 220.6ms
# Speed: 15.6ms preprocess, 220.6ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 footer, 323.7ms
# Speed: 15.6ms preprocess, 323.7ms inference, 1.1ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 4 paragraphs, 1 numbered_list, 1 footer, 236.4ms
# Speed: 0.0ms preprocess, 236.4ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 footer, 219.9ms
# Speed: 5.5ms preprocess, 219.9ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 3 paragraphs, 1 footer, 220.2ms
# Speed: 0.0ms preprocess, 220.2ms inference, 15.7ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 3 pictures, 1 footer, 235.8ms
# Speed: 15.0ms preprocess, 235.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 title, 1 paragraph, 1 header, 235.9ms
# Speed: 0.0ms preprocess, 235.9ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 3 paragraphs, 1 header, 247.2ms
# Speed: 0.0ms preprocess, 247.2ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 header, 235.7ms
# Speed: 0.0ms preprocess, 235.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 header, 298.7ms
# Speed: 15.6ms preprocess, 298.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 paragraph, 1 picture, 1 numbered_list, 1 header, 220.2ms
# Speed: 15.6ms preprocess, 220.2ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 header, 1 footnote, 221.2ms
# Speed: 15.6ms preprocess, 221.2ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 header, 231.4ms
# Speed: 4.0ms preprocess, 231.4ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 2 titles, 1 table, 1 marked_list, 1 header, 235.4ms
# Speed: 15.6ms preprocess, 235.4ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 picture, 1 header, 248.4ms
# Speed: 0.0ms preprocess, 248.4ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 2 paragraphs, 1 header, 219.6ms
# Speed: 15.6ms preprocess, 219.6ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 3 paragraphs, 1 header, 220.0ms
# Speed: 15.6ms preprocess, 220.0ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 pictures, 1 header, 219.7ms
# Speed: 13.5ms preprocess, 219.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 table, 235.3ms
# Speed: 0.0ms preprocess, 235.3ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 table, 1 picture, 297.9ms
# Speed: 15.6ms preprocess, 297.9ms inference, 15.6ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 2 paragraphs, 1 picture, 1 table_signature, 1 numbered_list, 235.4ms
# Speed: 0.0ms preprocess, 235.4ms inference, 10.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 paragraph, 1 numbered_list, 228.1ms
# Speed: 15.6ms preprocess, 228.1ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 250.9ms
# Speed: 0.0ms preprocess, 250.9ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 4 paragraphs, 2 pictures, 219.8ms
# Speed: 0.0ms preprocess, 219.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 numbered_list, 1 footnote, 220.1ms
# Speed: 15.5ms preprocess, 220.1ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 219.8ms
# Speed: 0.0ms preprocess, 219.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 title, 2 paragraphs, 1 footer, 1 footnote, 235.8ms
# Speed: 0.0ms preprocess, 235.8ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 3 paragraphs, 1 table, 1 picture, 1 footer, 220.2ms
# Speed: 0.0ms preprocess, 220.2ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 footer, 251.0ms
# Speed: 15.6ms preprocess, 251.0ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 3 paragraphs, 1 footer, 218.0ms
# Speed: 18.6ms preprocess, 218.0ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 1 picture, 1 numbered_list, 1 footer, 235.2ms
# Speed: 16.6ms preprocess, 235.2ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 footer, 235.0ms
# Speed: 15.6ms preprocess, 235.0ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 5 paragraphs, 1 picture, 1 footer, 235.3ms
# Speed: 0.0ms preprocess, 235.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 numbered_list, 1 footer, 251.0ms
# Speed: 0.0ms preprocess, 251.0ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 title, 4 paragraphs, 1 marked_list, 1 footer, 225.5ms
# Speed: 10.0ms preprocess, 225.5ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 4 paragraphs, 1 table, 1 picture, 1 footer, 220.6ms
# Speed: 7.0ms preprocess, 220.6ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 3 paragraphs, 1 numbered_list, 1 footer, 242.5ms
# Speed: 0.0ms preprocess, 242.5ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 3 paragraphs, 1 table, 1 picture, 1 footer, 220.1ms
# Speed: 0.0ms preprocess, 220.1ms inference, 15.6ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 numbered_list, 1 footer, 220.1ms
# Speed: 0.0ms preprocess, 220.1ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 numbered_list, 1 footer, 1 footnote, 220.6ms
# Speed: 15.6ms preprocess, 220.6ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 2 paragraphs, 1 numbered_list, 1 footer, 1 footnote, 220.6ms
# Speed: 15.6ms preprocess, 220.6ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 footer, 226.7ms
# Speed: 16.1ms preprocess, 226.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 footer, 235.7ms
# Speed: 15.6ms preprocess, 235.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 3 paragraphs, 2 pictures, 1 numbered_list, 1 footer, 242.2ms
# Speed: 8.9ms preprocess, 242.2ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 marked_list, 1 footer, 235.7ms
# Speed: 15.6ms preprocess, 235.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 picture, 1 footer, 232.8ms
# Speed: 3.0ms preprocess, 232.8ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 4 paragraphs, 1 header, 1 footer, 235.8ms
# Speed: 0.0ms preprocess, 235.8ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 picture, 1 header, 1 footer, 250.7ms
# Speed: 15.6ms preprocess, 250.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 table, 2 pictures, 1 picture_signature, 1 header, 1 footer, 235.3ms
# Speed: 16.1ms preprocess, 235.3ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 table, 1 marked_list, 1 header, 1 footer, 229.1ms
# Speed: 0.0ms preprocess, 229.1ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 picture, 2 numbered_lists, 1 header, 1 footer, 230.3ms
# Speed: 27.4ms preprocess, 230.3ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 titles, 2 paragraphs, 1 numbered_list, 1 marked_list, 1 header, 1 footer, 277.1ms
# Speed: 3.2ms preprocess, 277.1ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 header, 1 footer, 235.3ms
# Speed: 0.0ms preprocess, 235.3ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 numbered_list, 1 header, 1 footer, 238.3ms
# Speed: 0.0ms preprocess, 238.3ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 header, 1 footer, 219.6ms
# Speed: 15.6ms preprocess, 219.6ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 3 pictures, 1 header, 1 footer, 219.7ms
# Speed: 0.0ms preprocess, 219.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 picture, 1 header, 1 footer, 257.0ms
# Speed: 10.0ms preprocess, 257.0ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 picture, 1 header, 1 footer, 239.8ms
# Speed: 0.0ms preprocess, 239.8ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 header, 1 footer, 235.7ms
# Speed: 15.6ms preprocess, 235.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 3 paragraphs, 3 pictures, 1 header, 1 footer, 219.7ms
# Speed: 15.6ms preprocess, 219.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 header, 1 footer, 313.9ms
# Speed: 0.0ms preprocess, 313.9ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 title, 1 paragraph, 1 header, 1 footer, 235.9ms
# Speed: 0.0ms preprocess, 235.9ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 title, 3 paragraphs, 1 header, 1 footer, 235.8ms
# Speed: 0.0ms preprocess, 235.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 header, 1 footer, 232.4ms
# Speed: 0.0ms preprocess, 232.4ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 2 pictures, 2 numbered_lists, 1 header, 250.4ms
# Speed: 15.5ms preprocess, 250.4ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 header, 1 footer, 235.3ms
# Speed: 0.0ms preprocess, 235.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 numbered_list, 1 header, 275.2ms
# Speed: 15.6ms preprocess, 275.2ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 header, 222.7ms
# Speed: 15.6ms preprocess, 222.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 3 paragraphs, 1 header, 1 footer, 223.1ms
# Speed: 15.6ms preprocess, 223.1ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 header, 1 footer, 235.5ms
# Speed: 0.0ms preprocess, 235.5ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 header, 1 footer, 221.0ms
# Speed: 15.6ms preprocess, 221.0ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 3 paragraphs, 1 numbered_list, 1 header, 217.9ms
# Speed: 8.7ms preprocess, 217.9ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 paragraph, 1 header, 215.8ms
# Speed: 4.5ms preprocess, 215.8ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 2 paragraphs, 1 numbered_list, 1 marked_list, 235.3ms
# Speed: 0.0ms preprocess, 235.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 title, 1 numbered_list, 1 header, 1 footnote, 220.1ms
# Speed: 15.6ms preprocess, 220.1ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 3 pictures, 1 header, 1 footer, 235.2ms
# Speed: 0.0ms preprocess, 235.2ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 3 paragraphs, 1 header, 225.3ms
# Speed: 0.0ms preprocess, 225.3ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 title, 2 paragraphs, 1 table, 1 picture, 1 numbered_list, 1 header, 235.1ms
# Speed: 0.0ms preprocess, 235.1ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 1 paragraph, 1 picture, 1 numbered_list, 1 marked_list, 1 header, 229.7ms
# Speed: 15.6ms preprocess, 229.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 title, 3 paragraphs, 1 picture, 1 numbered_list, 1 marked_list, 1 header, 1 footer, 219.7ms
# Speed: 15.6ms preprocess, 219.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 header, 235.7ms
# Speed: 15.7ms preprocess, 235.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 paragraph, 1 header, 1 footer, 219.2ms
# Speed: 15.6ms preprocess, 219.2ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 paragraph, 1 header, 1 footer, 220.1ms
# Speed: 15.6ms preprocess, 220.1ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 header, 1 footer, 220.1ms
# Speed: 0.0ms preprocess, 220.1ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 3 paragraphs, 1 picture, 1 header, 1 footer, 235.3ms
# Speed: 0.0ms preprocess, 235.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 header, 1 footer, 235.5ms
# Speed: 0.0ms preprocess, 235.5ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 header, 1 footer, 323.9ms
# Speed: 6.2ms preprocess, 323.9ms inference, 15.5ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 title, 1 header, 1 footer, 1 footnote, 235.9ms
# Speed: 0.0ms preprocess, 235.9ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 titles, 1 paragraph, 1 table, 2 pictures, 1 numbered_list, 1 header, 1 footer, 224.6ms
# Speed: 8.6ms preprocess, 224.6ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 numbered_list, 1 header, 1 footer, 1 footnote, 251.3ms
# Speed: 0.0ms preprocess, 251.3ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 header, 1 footer, 254.4ms
# Speed: 0.0ms preprocess, 254.4ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 4 paragraphs, 1 header, 1 footer, 238.7ms
# Speed: 15.6ms preprocess, 238.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 title, 2 paragraphs, 2 pictures, 1 picture_signature, 1 numbered_list, 1 marked_list, 1 footnote, 232.9ms
# Speed: 9.1ms preprocess, 232.9ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 2 paragraphs, 1 picture, 235.3ms
# Speed: 0.0ms preprocess, 235.3ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 picture, 1 footnote, 220.5ms
# Speed: 15.6ms preprocess, 220.5ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 1 paragraph, 1 table, 1 numbered_list, 219.7ms
# Speed: 15.6ms preprocess, 219.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 4 paragraphs, 1 picture, 210.3ms
# Speed: 10.5ms preprocess, 210.3ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 3 pictures, 1 numbered_list, 1 marked_list, 219.4ms
# Speed: 15.6ms preprocess, 219.4ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 3 paragraphs, 2 pictures, 1 marked_list, 235.9ms
# Speed: 0.0ms preprocess, 235.9ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 1 paragraph, 1 table, 235.3ms
# Speed: 15.6ms preprocess, 235.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 titles, 1 paragraph, 3 pictures, 235.4ms
# Speed: 0.0ms preprocess, 235.4ms inference, 15.6ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 235.5ms
# Speed: 15.6ms preprocess, 235.5ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 titles, 1 paragraph, 1 table, 1 picture, 235.4ms
# Speed: 0.0ms preprocess, 235.4ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 3 paragraphs, 1 picture, 2 marked_lists, 235.3ms
# Speed: 0.0ms preprocess, 235.3ms inference, 15.6ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 1 paragraph, 1 numbered_list, 250.9ms
# Speed: 0.0ms preprocess, 250.9ms inference, 15.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 219.6ms
# Speed: 15.6ms preprocess, 219.6ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 1 picture, 1 picture_signature, 235.7ms
# Speed: 16.1ms preprocess, 235.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 1 table, 220.8ms
# Speed: 11.6ms preprocess, 220.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 3 paragraphs, 1 numbered_list, 228.2ms
# Speed: 23.1ms preprocess, 228.2ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 313.4ms
# Speed: 5.0ms preprocess, 313.4ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 3 paragraphs, 1 table, 1 picture, 1 footnote, 219.7ms
# Speed: 15.6ms preprocess, 219.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 footnote, 220.2ms
# Speed: 16.0ms preprocess, 220.2ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 3 paragraphs, 1 header, 1 footer, 220.7ms
# Speed: 15.6ms preprocess, 220.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 2 paragraphs, 1 header, 1 footer, 220.3ms
# Speed: 15.6ms preprocess, 220.3ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 picture, 1 header, 1 footer, 1 footnote, 238.2ms
# Speed: 22.9ms preprocess, 238.2ms inference, 6.5ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 header, 1 footer, 2 footnotes, 283.1ms
# Speed: 15.6ms preprocess, 283.1ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 2 pictures, 1 header, 1 footer, 298.2ms
# Speed: 12.0ms preprocess, 298.2ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 3 paragraphs, 1 header, 1 footer, 314.1ms
# Speed: 0.0ms preprocess, 314.1ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 header, 1 footer, 233.2ms
# Speed: 0.0ms preprocess, 233.2ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 table, 1 header, 1 footer, 219.0ms
# Speed: 15.6ms preprocess, 219.0ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 picture, 1 header, 1 footer, 224.7ms
# Speed: 15.0ms preprocess, 224.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 3 paragraphs, 1 header, 1 footer, 236.3ms
# Speed: 0.0ms preprocess, 236.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 numbered_list, 1 header, 1 footer, 225.6ms
# Speed: 9.9ms preprocess, 225.6ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 5 paragraphs, 1 header, 1 footer, 235.2ms
# Speed: 15.6ms preprocess, 235.2ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 titles, 1 paragraph, 1 picture, 1 marked_list, 1 header, 1 footer, 1 footnote, 235.3ms
# Speed: 15.6ms preprocess, 235.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 picture, 1 marked_list, 1 header, 1 footer, 235.2ms
# Speed: 0.0ms preprocess, 235.2ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 header, 1 footer, 236.4ms
# Speed: 0.0ms preprocess, 236.4ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 title, 3 paragraphs, 2 numbered_lists, 1 header, 1 footer, 220.2ms
# Speed: 0.0ms preprocess, 220.2ms inference, 15.6ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 3 paragraphs, 1 header, 1 footer, 220.1ms
# Speed: 15.6ms preprocess, 220.1ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 header, 1 footer, 220.2ms
# Speed: 15.6ms preprocess, 220.2ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 1 paragraph, 2 tables, 3 pictures, 1 header, 1 footer, 235.8ms
# Speed: 15.6ms preprocess, 235.8ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 table, 1 header, 1 footer, 1 footnote, 267.5ms
# Speed: 0.0ms preprocess, 267.5ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 paragraph, 1 numbered_list, 1 header, 236.3ms
# Speed: 0.0ms preprocess, 236.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 header, 224.8ms
# Speed: 15.6ms preprocess, 224.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 3 pictures, 1 header, 1 footer, 219.7ms
# Speed: 15.6ms preprocess, 219.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 2 paragraphs, 2 numbered_lists, 1 marked_list, 1 header, 1 footer, 228.1ms
# Speed: 3.1ms preprocess, 228.1ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 numbered_list, 1 header, 1 footer, 230.5ms
# Speed: 0.0ms preprocess, 230.5ms inference, 6.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 picture, 1 header, 1 footer, 220.1ms
# Speed: 0.0ms preprocess, 220.1ms inference, 15.6ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 header, 1 footer, 220.6ms
# Speed: 15.6ms preprocess, 220.6ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 title, 4 paragraphs, 1 table, 3 pictures, 1 header, 1 footer, 230.4ms
# Speed: 7.4ms preprocess, 230.4ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 marked_list, 1 header, 1 footer, 219.6ms
# Speed: 15.6ms preprocess, 219.6ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 header, 230.1ms
# Speed: 6.5ms preprocess, 230.1ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 1 numbered_list, 1 header, 220.2ms
# Speed: 15.6ms preprocess, 220.2ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 header, 1 footer, 219.7ms
# Speed: 15.6ms preprocess, 219.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 2 pictures, 1 header, 219.7ms
# Speed: 15.6ms preprocess, 219.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 3 paragraphs, 1 header, 1 footer, 235.3ms
# Speed: 0.0ms preprocess, 235.3ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 table, 1 picture, 1 header, 1 footer, 235.3ms
# Speed: 0.0ms preprocess, 235.3ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 3 paragraphs, 2 pictures, 1 header, 1 footer, 215.7ms
# Speed: 4.5ms preprocess, 215.7ms inference, 15.6ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 3 paragraphs, 1 marked_list, 1 header, 1 footer, 235.8ms
# Speed: 0.0ms preprocess, 235.8ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 numbered_list, 1 header, 1 footer, 1 footnote, 219.6ms
# Speed: 15.6ms preprocess, 219.6ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 3 paragraphs, 1 header, 1 footer, 220.2ms
# Speed: 0.0ms preprocess, 220.2ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 1 numbered_list, 1 header, 222.3ms
# Speed: 0.0ms preprocess, 222.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 header, 211.5ms
# Speed: 9.7ms preprocess, 211.5ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 2 titles, 2 paragraphs, 2 tables, 1 picture, 1 header, 1 footer, 233.7ms
# Speed: 0.0ms preprocess, 233.7ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 4 paragraphs, 1 marked_list, 1 header, 1 footer, 1 footnote, 241.4ms
# Speed: 0.0ms preprocess, 241.4ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 header, 1 footer, 1 footnote, 219.9ms
# Speed: 15.6ms preprocess, 219.9ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 3 paragraphs, 1 header, 1 footer, 241.2ms
# Speed: 0.0ms preprocess, 241.2ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 header, 1 footer, 219.8ms
# Speed: 15.6ms preprocess, 219.8ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 header, 1 footer, 220.1ms
# Speed: 15.6ms preprocess, 220.1ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 table, 1 header, 1 footer, 1 footnote, 225.9ms
# Speed: 7.0ms preprocess, 225.9ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 header, 1 footer, 1 footnote, 240.2ms
# Speed: 0.0ms preprocess, 240.2ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 2 pictures, 1 header, 219.7ms
# Speed: 0.0ms preprocess, 219.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 header, 1 footer, 235.7ms
# Speed: 0.0ms preprocess, 235.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 title, 1 paragraph, 1 header, 1 footer, 2 footnotes, 219.7ms
# Speed: 10.0ms preprocess, 219.7ms inference, 15.5ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 header, 1 footer, 1 footnote, 235.9ms
# Speed: 15.6ms preprocess, 235.9ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 4 paragraphs, 1 numbered_list, 219.7ms
# Speed: 0.0ms preprocess, 219.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 3 paragraphs, 1 picture, 2 numbered_lists, 220.2ms
# Speed: 15.6ms preprocess, 220.2ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 220.2ms
# Speed: 0.0ms preprocess, 220.2ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 title, 2 paragraphs, 217.1ms
# Speed: 7.5ms preprocess, 217.1ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 235.7ms
# Speed: 0.0ms preprocess, 235.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 table, 1 picture, 1 table_signature, 224.2ms
# Speed: 6.8ms preprocess, 224.2ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 table, 220.0ms
# Speed: 15.6ms preprocess, 220.0ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 numbered_list, 219.7ms
# Speed: 0.0ms preprocess, 219.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 (no detections), 250.9ms
# Speed: 15.6ms preprocess, 250.9ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 3 paragraphs, 1 numbered_list, 221.2ms
# Speed: 9.5ms preprocess, 221.2ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 235.8ms
# Speed: 0.0ms preprocess, 235.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 3 pictures, 234.8ms
# Speed: 0.0ms preprocess, 234.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 picture, 219.7ms
# Speed: 7.5ms preprocess, 219.7ms inference, 15.6ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 1 paragraph, 1 picture, 1 picture_signature, 219.8ms
# Speed: 0.0ms preprocess, 219.8ms inference, 15.6ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 3 paragraphs, 220.0ms
# Speed: 0.0ms preprocess, 220.0ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 235.8ms
# Speed: 0.0ms preprocess, 235.8ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 paragraph, 2 pictures, 1 marked_list, 1 header, 1 footer, 220.4ms
# Speed: 15.6ms preprocess, 220.4ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 title, 1 header, 1 footer, 2 footnotes, 226.4ms
# Speed: 7.5ms preprocess, 226.4ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 table, 1 picture, 1 numbered_list, 1 marked_list, 1 header, 1 footer, 214.0ms
# Speed: 6.5ms preprocess, 214.0ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 titles, 3 paragraphs, 2 pictures, 1 header, 1 footer, 219.6ms
# Speed: 0.0ms preprocess, 219.6ms inference, 15.6ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 title, 1 paragraph, 1 table, 1 marked_list, 1 header, 1 footer, 1 footnote, 235.8ms
# Speed: 0.0ms preprocess, 235.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 2 pictures, 1 header, 1 footer, 236.7ms
# Speed: 0.0ms preprocess, 236.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 header, 1 footer, 267.4ms
# Speed: 15.7ms preprocess, 267.4ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 4 paragraphs, 1 header, 1 footer, 235.7ms
# Speed: 0.0ms preprocess, 235.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 3 paragraphs, 1 header, 1 footer, 220.1ms
# ...
# Speed: 9.0ms preprocess, 298.3ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 header, 1 footer, 269.1ms
# Speed: 7.0ms preprocess, 269.1ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 header, 1 footer, 242.1ms
# Speed: 8.0ms preprocess, 242.1ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 picture, 1 header, 1 footer, 238.5ms
# Speed: 7.5ms preprocess, 238.5ms inference, 1.6ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 picture, 2 marked_lists, 1 header, 1 footer, 234.0ms
# Speed: 7.0ms preprocess, 234.0ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 header, 1 footer, 245.2ms
# Speed: 10.0ms preprocess, 245.2ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 header, 1 footer, 292.0ms
# Speed: 11.0ms preprocess, 292.0ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 header, 1 footer, 276.0ms
# Speed: 12.0ms preprocess, 276.0ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 header, 1 footer, 240.0ms
# Speed: 7.0ms preprocess, 240.0ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 header, 1 footer, 241.7ms
# Speed: 9.0ms preprocess, 241.7ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 title, 1 paragraph, 1 picture, 1 numbered_list, 1 header, 1 footer, 239.0ms
# Speed: 8.0ms preprocess, 239.0ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 header, 1 footer, 238.7ms
# Speed: 8.0ms preprocess, 238.7ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 header, 1 footer, 288.6ms
# Speed: 9.0ms preprocess, 288.6ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 2 paragraphs, 1 marked_list, 1 header, 1 footer, 237.7ms
# Speed: 8.0ms preprocess, 237.7ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 title, 3 paragraphs, 1 table, 3 pictures, 1 numbered_list, 1 header, 1 footer, 237.6ms
# Speed: 9.1ms preprocess, 237.6ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 title, 2 paragraphs, 2 numbered_lists, 1 header, 235.7ms
# Speed: 7.6ms preprocess, 235.7ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 title, 1 paragraph, 2 tables, 1 marked_list, 1 header, 236.0ms
# Speed: 8.0ms preprocess, 236.0ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 1 paragraph, 1 header, 232.6ms
# Speed: 8.0ms preprocess, 232.6ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 title, 1 paragraph, 1 header, 1 footnote, 253.6ms
# Speed: 7.0ms preprocess, 253.6ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 header, 1 footnote, 252.6ms
# Speed: 11.0ms preprocess, 252.6ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 picture, 1 marked_list, 2 headers, 2 footnotes, 245.4ms
# Speed: 7.5ms preprocess, 245.4ms inference, 2.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 2 paragraphs, 1 table, 1 header, 243.0ms
# Speed: 10.0ms preprocess, 243.0ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 header, 1 footnote, 271.9ms
# Speed: 8.0ms preprocess, 271.9ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 1 numbered_list, 1 header, 279.0ms
# Speed: 7.0ms preprocess, 279.0ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 header, 261.4ms
# Speed: 9.0ms preprocess, 261.4ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 title, 1 paragraph, 1 table, 1 marked_list, 296.2ms
# Speed: 10.0ms preprocess, 296.2ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 1 paragraph, 1 header, 1 footnote, 300.7ms
# Speed: 13.0ms preprocess, 300.7ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 titles, 1 paragraph, 1 picture, 1 header, 288.7ms
# Speed: 12.6ms preprocess, 288.7ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 table, 1 picture, 1 picture_signature, 2 marked_lists, 280.4ms
# Speed: 29.5ms preprocess, 280.4ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 1 paragraph, 1 header, 1 footnote, 301.1ms
# Speed: 9.6ms preprocess, 301.1ms inference, 2.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 2 pictures, 1 marked_list, 258.4ms
# Speed: 7.0ms preprocess, 258.4ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 3 paragraphs, 3 pictures, 262.0ms
# Speed: 12.0ms preprocess, 262.0ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 3 paragraphs, 1 header, 223.3ms
# Speed: 8.0ms preprocess, 223.3ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 2 paragraphs, 2 pictures, 1 table_signature, 1 header, 242.6ms
# Speed: 8.0ms preprocess, 242.6ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 3 paragraphs, 1 marked_list, 1 header, 323.9ms
# Speed: 6.6ms preprocess, 323.9ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 4 paragraphs, 1 picture, 1 marked_list, 1 header, 247.6ms
# Speed: 10.5ms preprocess, 247.6ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 3 paragraphs, 1 header, 295.5ms
# Speed: 11.3ms preprocess, 295.5ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 2 paragraphs, 1 header, 233.8ms
# Speed: 7.0ms preprocess, 233.8ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 paragraph, 1 header, 228.7ms
# Speed: 15.6ms preprocess, 228.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 marked_list, 1 header, 252.1ms
# Speed: 20.5ms preprocess, 252.1ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 marked_list, 1 header, 234.2ms
# Speed: 16.4ms preprocess, 234.2ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 1 paragraph, 1 table, 1 picture, 1 marked_list, 1 header, 264.3ms
# Speed: 0.0ms preprocess, 264.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 marked_list, 1 header, 260.2ms
# Speed: 7.4ms preprocess, 260.2ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 header, 2 footnotes, 359.9ms
# Speed: 15.3ms preprocess, 359.9ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 titles, 1 header, 237.4ms
# Speed: 7.0ms preprocess, 237.4ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 3 paragraphs, 1 marked_list, 1 header, 237.3ms
# Speed: 7.0ms preprocess, 237.3ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 titles, 1 paragraph, 291.0ms
# Speed: 9.0ms preprocess, 291.0ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 table, 1 numbered_list, 285.4ms
# Speed: 8.0ms preprocess, 285.4ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 numbered_list, 289.4ms
# Speed: 9.1ms preprocess, 289.4ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 table, 1 numbered_list, 1 footnote, 244.3ms
# Speed: 8.0ms preprocess, 244.3ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 2 paragraphs, 1 picture, 1 marked_list, 275.4ms
# Speed: 7.0ms preprocess, 275.4ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 numbered_list, 2 marked_lists, 238.4ms
# Speed: 7.0ms preprocess, 238.4ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 2 paragraphs, 1 picture, 239.3ms
# Speed: 6.0ms preprocess, 239.3ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 2 paragraphs, 1 picture, 241.3ms
# Speed: 7.0ms preprocess, 241.3ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 4 paragraphs, 1 table, 1 picture, 231.4ms
# Speed: 7.0ms preprocess, 231.4ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 2 pictures, 2 numbered_lists, 1 footnote, 263.3ms
# Speed: 9.0ms preprocess, 263.3ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 5 paragraphs, 3 pictures, 1 numbered_list, 236.2ms
# Speed: 9.0ms preprocess, 236.2ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 title, 2 paragraphs, 2 pictures, 1 numbered_list, 1 marked_list, 1 header, 240.4ms
# Speed: 7.0ms preprocess, 240.4ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 numbered_list, 1 header, 236.6ms
# Speed: 7.0ms preprocess, 236.6ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 picture, 1 numbered_list, 1 header, 237.0ms
# Speed: 7.0ms preprocess, 237.0ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 table, 1 header, 1 footer, 277.2ms
# Speed: 8.0ms preprocess, 277.2ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 1 paragraph, 1 picture, 1 numbered_list, 1 header, 239.9ms
# Speed: 7.0ms preprocess, 239.9ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 1 paragraph, 1 numbered_list, 1 header, 238.5ms
# Speed: 7.0ms preprocess, 238.5ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 header, 239.0ms
# Speed: 7.0ms preprocess, 239.0ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 1 paragraph, 1 header, 1 footer, 241.6ms
# Speed: 7.5ms preprocess, 241.6ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 2 pictures, 1 numbered_list, 1 header, 236.0ms
# Speed: 8.0ms preprocess, 236.0ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 header, 1 footer, 1 footnote, 292.1ms
# Speed: 15.0ms preprocess, 292.1ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 header, 256.0ms
# Speed: 7.0ms preprocess, 256.0ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 table, 1 numbered_list, 1 marked_list, 1 header, 238.0ms
# Speed: 8.0ms preprocess, 238.0ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 1 paragraph, 1 header, 237.0ms
# Speed: 7.0ms preprocess, 237.0ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 1 paragraph, 1 header, 1 footnote, 232.2ms
# Speed: 7.0ms preprocess, 232.2ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 1 paragraph, 1 numbered_list, 1 header, 1 footnote, 238.5ms
# Speed: 9.0ms preprocess, 238.5ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 picture, 1 marked_list, 1 header, 1 footnote, 259.6ms
# Speed: 13.5ms preprocess, 259.6ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 numbered_list, 1 header, 280.2ms
# Speed: 8.0ms preprocess, 280.2ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 numbered_list, 1 header, 260.5ms
# Speed: 7.5ms preprocess, 260.5ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 table, 3 pictures, 1 header, 306.0ms
# Speed: 8.0ms preprocess, 306.0ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 numbered_list, 1 header, 314.8ms
# Speed: 7.0ms preprocess, 314.8ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 89
#      86         y_pred.extend(pred_classes)
#      88 # 2. Рассчитываем метрики
# ---> 89 precision, recall, f1, _ = precision_recall_fscore_support(y_true, y_pred, average="weighted")
#      90 mIoU = average_precision_score(y_true, y_pred)  # Оценка mAP50-95 (приближённая)
#      91 fitness = (precision + recall + f1) / 3  # Условная метрика для общего качества
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1789, in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1626 """Compute precision, recall, F-measure and support for each class.
#    1627
#    1628 The precision is the ratio ``tp / (tp + fp)`` where ``tp`` is the number of
#    (...)
#    1786  array([2, 2, 2]))
#    1787 """
#    1788 _check_zero_division(zero_division)
# -> 1789 labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1791 # Calculate tp_sum, pred_sum, true_sum ###
#    1792 samplewise = average == "samples"
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1561, in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1558 if average not in average_options and average != "binary":
#    1559     raise ValueError("average has to be one of " + str(average_options))
# -> 1561 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    1562 # Convert to Python primitive type to avoid NumPy type / Python str
#    1563 # comparison. See https://github.com/numpy/numpy/issues/6784
#    1564 present_labels = unique_labels(y_true, y_pred).tolist()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:103, in _check_targets(y_true, y_pred)
#      76 """Check that y_true and y_pred belong to the same classification task.
#      77
#      78 This converts multiclass or binary types to a common shape, and raises a
#    (...)
#     100 y_pred : array or indicator matrix
#     101 """
#     102 xp, _ = get_namespace(y_true, y_pred)
# --> 103 check_consistent_length(y_true, y_pred)
#     104 type_true = type_of_target(y_true, input_name="y_true")
#     105 type_pred = type_of_target(y_pred, input_name="y_pred")
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:457, in check_consistent_length(*arrays)
#     455 uniques = np.unique(lengths)
#     456 if len(uniques) > 1:
# --> 457     raise ValueError(
#     458         "Found input variables with inconsistent numbers of samples: %r"
#     459         % [int(l) for l in lengths]
#     460     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [5789, 4425]

# %%
import os

# Путь к тестовому набору данных
test_data_path = r"C:\\Users\\Vito\\Jupyter\\Models\\test_1_grup_Tim"

# Проверяем существование необходимых папок
if not os.path.exists(os.path.join(test_data_path, "images")):
    raise FileNotFoundError(f"Папка с изображениями {os.path.join(test_data_path, 'images')} не найдена.")
if not os.path.exists(os.path.join(test_data_path, "labels")):
    raise FileNotFoundError(f"Папка с разметкой {os.path.join(test_data_path, 'labels')} не найдена.")

# Формируем YAML-строку с описанием тестового набора
test_data_yaml = (
    "path: " + test_data_path.replace("\\", "/") + "\n"
    "train: \"\"  # Пустой путь, так как обучение не требуется\n"
    "val: images\n"
    "names:\n"
    "  0: title\n"
    "  1: paragraph\n"
    "  2: table\n"
    "  3: picture\n"
    "  4: table_signature\n"
    "  5: picture_signature\n"
    "  6: numbered_list\n"
    "  7: marked_list\n"
    "  8: header\n"
    "  9: footer\n"
    "  10: footnote\n"
    "  11: formula\n"
)

# Сохраняем YAML-файл
yaml_path = os.path.join(test_data_path, "test.yaml")
with open(yaml_path, "w", encoding="utf-8") as file:
    file.write(test_data_yaml)

print(f"Файл YAML для тестового набора сохранён в: {yaml_path}")

# Выполняем валидацию на тестовом наборе
results = model.val(data=yaml_path)

# Получаем метрики из results_dict
metrics = results.results_dict

# Извлекаем precision и recall
precision = metrics['metrics/precision(B)']
recall = metrics['metrics/recall(B)']

# Вычисляем F1 Score
f1_score = 2 * (precision * recall) / (precision + recall)

# Извлекаем mIoU (mAP50-95)
mAP50_95 = metrics['metrics/mAP50-95(B)']

# Печатаем метрики
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1_score)
print("mIoU (mAP50-95):", mAP50_95)
print("Fitness:", metrics['fitness'])
# Out:
# Файл YAML для тестового набора сохранён в: C:\\Users\\Vito\\Jupyter\\Models\\test_1_grup_Tim\test.yaml
# Ultralytics 8.3.34  Python-3.11.9 torch-2.5.1+cpu CPU (AMD Ryzen 7 7840HS w/ Radeon 780M Graphics)
# val: Scanning C:\Users\Vito\Jupyter\Models\test_1_grup_Tim\labels... 984 images, 0 backgrounds, 0 corrupt: 100%|███████
# val: New cache created: C:\Users\Vito\Jupyter\Models\test_1_grup_Tim\labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 62/62 [06:22
#                    all        984       5789      0.412      0.393      0.417      0.307
#                  title        413        413      0.365      0.446      0.295      0.177
#              paragraph        805       1173      0.394      0.747      0.549      0.441
#                  table        180        180      0.696      0.611      0.671      0.441
#                picture        159        175        0.3      0.971      0.752      0.634
#        table_signature        177        177     0.0464    0.00262     0.0619     0.0471
#      picture_signature        159        175      0.346     0.0333      0.207      0.144
#          numbered_list        429        514       0.37      0.319      0.314      0.261
#            marked_list        408        481      0.443      0.233      0.268      0.214
#                 header        941        941      0.989      0.775      0.978      0.672
#                 footer        891        891          1      0.584      0.906      0.652
#               footnote        212        303          0          0          0          0
#                formula        184        366          0          0      0.004     0.0028
# Speed: 1.6ms preprocess, 278.1ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to runs\detect\val2
# Precision: 0.41246092361403547
# Recall: 0.39342211234263597
# F1 Score: 0.4027166240927127
# mIoU (mAP50-95): 0.30716015994620244
# Fitness: 0.31816296613258194

# %%
Обработка test_2_grup_Tim

# %%
import os

# Пути к папкам
png_dir = "C:\\Users\\Vito\\Jupyter\\Models\\test_2_grup_Tim\\images"  # Папка с PNG
json_dir = "C:\\Users\\Vito\\Jupyter\\Models\\test_2_grup_Tim\\json"  # Папка с JSON

# Получаем базовые имена файлов (без расширений)
png_files = {os.path.splitext(f)[0] for f in os.listdir(png_dir) if f.endswith(".png")}
json_files = {os.path.splitext(f)[0] for f in os.listdir(json_dir) if f.endswith(".json")}

# Выявляем лишние файлы
extra_png_files = png_files - json_files  # PNG, которых нет в JSON
extra_json_files = json_files - png_files  # JSON, которых нет в PNG

# Вывод результата
print(f"Лишние PNG файлы ({len(extra_png_files)}):", extra_png_files)
print(f"Лишние JSON файлы ({len(extra_json_files)}):", extra_json_files)

# Записать результат в файлы для анализа
with open("extra_png_files.txt", "w") as f:
    f.write("\n".join(sorted(extra_png_files)))

with open("extra_json_files.txt", "w") as f:
    f.write("\n".join(sorted(extra_json_files)))

print("Проверка завершена. Результаты записаны в extra_png_files.txt и extra_json_files.txt.")
# Out:
# Лишние PNG файлы (0): set()
# Лишние JSON файлы (0): set()
# Проверка завершена. Результаты записаны в extra_png_files.txt и extra_json_files.txt.

# %%
# Предобработка данных
import os
import json

# Папки
json_dir = "C:\\Users\\Vito\\Jupyter\\Models\\test_2_grup_Tim\\json"  # Путь к папке с JSON
images_dir = "C:\\Users\\Vito\\Jupyter\\Models\\test_2_grup_Tim\\images"    # Путь к изображениям
output_dir = "C:\\Users\\Vito\\Jupyter\\Models\\test_2_grup_Tim\\labels"  # Папка для сохранения YOLO разметки

# Словарь классов
class_mapping = {
    "title": 0,
    "paragraph": 1,
    "table": 2,
    "picture": 3,
    "graph": 3,
    "table_signature": 4,
    "picture_signature": 5,
    "numbered_list": 6,
    "marked_list": 7,
    "header": 8,
    "footer": 9,
    "footnote": 10,
    "formula": 11
}

# Создаем выходную папку
os.makedirs(output_dir, exist_ok=True)

# Функция для нормализации координат
def normalize_bbox(bbox, img_width, img_height):
    x1, y1, x2, y2 = bbox
    x_center = (x1 + x2) / 2 / img_width
    y_center = (y1 + y2) / 2 / img_height
    width = (x2 - x1) / img_width
    height = (y2 - y1) / img_height
    return x_center, y_center, width, height

# Проход по JSON файлам
for json_file in os.listdir(json_dir):
    if json_file.endswith(".json"):
        # Открываем JSON файл
        with open(os.path.join(json_dir, json_file), "r") as f:
            data = json.load(f)
        
        img_width = data["image_width"]
        img_height = data["image_height"]
        txt_filename = os.path.splitext(json_file)[0] + ".txt"
        txt_path = os.path.join(output_dir, txt_filename)
        
        # Запись данных в YOLO формат
        with open(txt_path, "w") as txt_file:
            for class_name, bboxes in data.items():
                if class_name in class_mapping:
                    class_id = class_mapping[class_name]
                    for bbox in bboxes:
                        x_center, y_center, width, height = normalize_bbox(bbox, img_width, img_height)
                        txt_file.write(f"{class_id} {x_center} {y_center} {width} {height}\n")

# %%
import os
import cv2
from ultralytics import YOLO
from PIL import Image
from pathlib import Path
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import average_precision_score
import numpy as np

# Пути
input_images_dir = "C:\\Users\\Vito\\Jupyter\\Models\\test_2_grup_Tim\\images"  # Папка с изображениями документов
labels_dir = "C:\\Users\\Vito\\Jupyter\\Models\\test_2_grup_Tim\\labels"  # Папка с разметкой YOLO
output_images_dir = "C:\\Users\\Vito\\Jupyter\\Models\\test_2_grup_Tim\\test_results"  # Папка для аннотированных изображений

# Создаём папку для аннотированных изображений, если она не существует
os.makedirs(output_images_dir, exist_ok=True)

# Загружаем модель YOLO
model = YOLO("C:\\Users\\Vito\\Jupyter\\Models\\runs YOLO11s datasetv3 aug imgsz=960\\detect\\train\\weights\\best.pt")

# Настройка кастомных порогов для каждого класса
custom_confidences = {
    0: 0.3,  # title
    1: 0.1,  # paragraph
    9: 0.1, # footer
    11: 0.1, # formula
    10: 0.4, # footnote
    6: 0.4, # numbered_list
    7: 0.4  # marked_list
}

# Список всех изображений в папке
image_files = [f for f in os.listdir(input_images_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
image_files.sort()  # Сортируем для упорядоченности

# 1. Обрабатываем изображения моделью YOLO и визуализируем предсказания с кастомными порогами
annotated_images = []
y_true, y_pred = [], []  # Для метрик

for image_file in image_files:
    image_path = os.path.join(input_images_dir, image_file)
    label_path = os.path.join(labels_dir, Path(image_file).stem + ".txt")  # Соответствующий файл разметки
    
    img = cv2.imread(image_path)

    # Применяем модель YOLO
    results = model.predict(source=img, conf=0.4, iou=0.51, save=False)
    
    # Фильтруем предсказания на основе кастомных порогов для классов
    filtered_boxes = []
    for result in results:
        for box in result.boxes:
            cls = int(box.cls)  # Класс объекта
            conf = float(box.conf)  # Уверенность объекта

            # Проверяем, превышает ли уверенность кастомный порог для данного класса
            if cls in custom_confidences:
                if conf >= custom_confidences[cls]:
                    filtered_boxes.append(box)
            else:
                # Используем общий порог (например, 0.4) для классов, для которых не задан кастомный порог
                if conf >= 0.4:
                    filtered_boxes.append(box)

        # Применяем отфильтрованные боксы для визуализации
        result.boxes = filtered_boxes

    # Наносим рамки на изображение
    annotated_img = results[0].plot()  # Визуализируем предсказания (аннотированное изображение)
    annotated_image_path = os.path.join(output_images_dir, image_file)
    cv2.imwrite(annotated_image_path, annotated_img)
    annotated_images.append(annotated_image_path)

    # Сравниваем с разметкой для метрик
    if os.path.exists(label_path):
        # Чтение разметки (ground truth)
        with open(label_path, "r") as f:
            true_boxes = [line.strip().split() for line in f.readlines()]
            true_classes = [int(box[0]) for box in true_boxes]  # Классы из разметки

        # Собираем предсказания
        pred_classes = [int(box.cls) for box in filtered_boxes]

        # Добавляем в список для метрик
        y_true.extend(true_classes)
        y_pred.extend(pred_classes)

# 2. Рассчитываем метрики
precision, recall, f1, _ = precision_recall_fscore_support(y_true, y_pred, average="weighted")
mIoU = average_precision_score(y_true, y_pred)  # Оценка mAP50-95 (приближённая)
fitness = (precision + recall + f1) / 3  # Условная метрика для общего качества

# Вывод метрик
print(f"Precision: {precision:.6f}")
print(f"Recall: {recall:.6f}")
print(f"F1 Score: {f1:.6f}")
print(f"mIoU (mAP50-95): {mIoU:.6f}")
print(f"Fitness: {fitness:.6f}")
# Out:
# 0: 960x768 1 title, 5 paragraphs, 1 table, 1 footnote, 282.9ms
# Speed: 8.9ms preprocess, 282.9ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 titles, 3 paragraphs, 1 picture, 1 numbered_list, 291.2ms
# Speed: 9.2ms preprocess, 291.2ms inference, 6.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 1 table, 1 numbered_list, 286.8ms
# Speed: 5.3ms preprocess, 286.8ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 4 paragraphs, 1 picture, 1 numbered_list, 2 marked_lists, 272.0ms
# Speed: 7.7ms preprocess, 272.0ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 236.2ms
# Speed: 12.5ms preprocess, 236.2ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 275.4ms
# Speed: 21.8ms preprocess, 275.4ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 title, 5 paragraphs, 1 picture, 1 header, 1 footer, 267.7ms
# Speed: 10.7ms preprocess, 267.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 2 paragraphs, 247.3ms
# Speed: 12.0ms preprocess, 247.3ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 4 paragraphs, 1 picture, 1 footnote, 260.0ms
# Speed: 13.8ms preprocess, 260.0ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 5 paragraphs, 1 table, 259.5ms
# Speed: 9.9ms preprocess, 259.5ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 titles, 6 paragraphs, 1 table, 1 picture, 1 footer, 272.8ms
# Speed: 9.5ms preprocess, 272.8ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 3 paragraphs, 1 formula, 276.6ms
# Speed: 9.6ms preprocess, 276.6ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 2 paragraphs, 1 table, 1 footer, 255.3ms
# Speed: 10.0ms preprocess, 255.3ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 title, 3 paragraphs, 1 footer, 254.2ms
# Speed: 7.0ms preprocess, 254.2ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 5 paragraphs, 1 footnote, 265.6ms
# Speed: 8.0ms preprocess, 265.6ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 3 paragraphs, 1 picture, 240.3ms
# Speed: 8.5ms preprocess, 240.3ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 1 table, 258.0ms
# Speed: 7.0ms preprocess, 258.0ms inference, 1.4ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 5 paragraphs, 2 pictures, 1 table_signature, 1 footnote, 272.4ms
# Speed: 9.1ms preprocess, 272.4ms inference, 1.2ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 326.9ms
# Speed: 9.1ms preprocess, 326.9ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 7 paragraphs, 2 pictures, 313.8ms
# Speed: 7.0ms preprocess, 313.8ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 6 paragraphs, 1 marked_list, 1 footnote, 252.0ms
# Speed: 7.5ms preprocess, 252.0ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 232.7ms
# Speed: 8.0ms preprocess, 232.7ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 274.3ms
# Speed: 8.0ms preprocess, 274.3ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 titles, 3 paragraphs, 1 table, 1 picture, 1 footnote, 242.6ms
# Speed: 8.0ms preprocess, 242.6ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 table, 1 picture, 1 numbered_list, 232.8ms
# Speed: 7.0ms preprocess, 232.8ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 2 footnotes, 270.4ms
# Speed: 7.0ms preprocess, 270.4ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 title, 1 paragraph, 1 table, 1 header, 1 footnote, 246.8ms
# Speed: 12.0ms preprocess, 246.8ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 4 paragraphs, 1 header, 241.9ms
# Speed: 6.0ms preprocess, 241.9ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 6 paragraphs, 1 picture, 1 numbered_list, 1 header, 235.8ms
# Speed: 10.0ms preprocess, 235.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 2 tables, 1 picture, 1 marked_list, 1 header, 235.7ms
# Speed: 3.6ms preprocess, 235.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 1 table, 2 pictures, 1 header, 251.5ms
# Speed: 0.0ms preprocess, 251.5ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 1 picture, 1 header, 1 footnote, 245.4ms
# Speed: 6.3ms preprocess, 245.4ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 table, 1 picture, 1 header, 251.4ms
# Speed: 0.0ms preprocess, 251.4ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 table, 2 numbered_lists, 1 header, 220.1ms
# Speed: 15.6ms preprocess, 220.1ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 picture, 1 header, 235.7ms
# Speed: 0.0ms preprocess, 235.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 1 table, 1 numbered_list, 1 header, 1 footnote, 235.7ms
# Speed: 15.6ms preprocess, 235.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 table, 1 picture, 1 header, 235.9ms
# Speed: 16.0ms preprocess, 235.9ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 2 paragraphs, 2 tables, 1 picture, 1 numbered_list, 1 header, 237.0ms
# Speed: 0.0ms preprocess, 237.0ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 3 paragraphs, 1 table, 1 numbered_list, 1 header, 235.8ms
# Speed: 15.6ms preprocess, 235.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 6 paragraphs, 1 picture, 267.5ms
# Speed: 0.0ms preprocess, 267.5ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 4 paragraphs, 1 marked_list, 1 header, 235.7ms
# Speed: 0.0ms preprocess, 235.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 5 paragraphs, 1 picture, 1 numbered_list, 1 header, 229.2ms
# Speed: 6.6ms preprocess, 229.2ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 numbered_list, 1 header, 235.8ms
# Speed: 15.6ms preprocess, 235.8ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 title, 3 paragraphs, 1 table, 1 marked_list, 1 header, 236.5ms
# Speed: 0.0ms preprocess, 236.5ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 picture, 1 numbered_list, 1 marked_list, 1 header, 235.7ms
# Speed: 0.0ms preprocess, 235.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 1 table, 2 pictures, 1 header, 219.6ms
# Speed: 15.6ms preprocess, 219.6ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 table, 1 header, 236.2ms
# Speed: 0.0ms preprocess, 236.2ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 1 footer, 263.9ms
# Speed: 0.0ms preprocess, 263.9ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 picture, 1 header, 1 footer, 267.0ms
# Speed: 0.0ms preprocess, 267.0ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 1 footer, 236.2ms
# Speed: 0.0ms preprocess, 236.2ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 3 paragraphs, 1 table, 1 numbered_list, 1 footer, 236.4ms
# Speed: 7.5ms preprocess, 236.4ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 title, 1 paragraph, 1 header, 1 footer, 1 footnote, 234.7ms
# Speed: 0.0ms preprocess, 234.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 table, 1 picture, 1 header, 1 footer, 236.1ms
# Speed: 16.0ms preprocess, 236.1ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 numbered_list, 1 header, 1 footer, 251.8ms
# Speed: 0.0ms preprocess, 251.8ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 3 paragraphs, 1 header, 1 footer, 1 footnote, 268.2ms
# Speed: 0.0ms preprocess, 268.2ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 title, 5 paragraphs, 1 picture, 1 header, 1 footer, 253.2ms
# Speed: 15.6ms preprocess, 253.2ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 picture, 1 footer, 267.3ms
# Speed: 0.0ms preprocess, 267.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 table, 1 header, 1 footer, 235.9ms
# Speed: 15.6ms preprocess, 235.9ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 table, 1 numbered_list, 1 footer, 236.0ms
# Speed: 0.0ms preprocess, 236.0ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 titles, 2 paragraphs, 1 numbered_list, 1 footer, 1 footnote, 252.3ms
# Speed: 15.6ms preprocess, 252.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 table, 1 picture, 1 footer, 1 footnote, 219.7ms
# Speed: 15.6ms preprocess, 219.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 footer, 251.6ms
# Speed: 0.0ms preprocess, 251.6ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 3 paragraphs, 1 picture, 1 numbered_list, 1 footer, 269.0ms
# Speed: 15.5ms preprocess, 269.0ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 footer, 265.8ms
# Speed: 6.1ms preprocess, 265.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 1 table, 1 numbered_list, 1 footer, 254.7ms
# Speed: 12.6ms preprocess, 254.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 3 paragraphs, 1 numbered_list, 1 footer, 241.3ms
# Speed: 9.2ms preprocess, 241.3ms inference, 15.6ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 4 paragraphs, 1 table, 2 pictures, 1 footer, 272.5ms
# Speed: 21.7ms preprocess, 272.5ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 title, 1 paragraph, 1 header, 1 footer, 270.7ms
# Speed: 8.6ms preprocess, 270.7ms inference, 0.9ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 2 paragraphs, 1 numbered_list, 1 header, 254.1ms
# Speed: 12.5ms preprocess, 254.1ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 1 picture, 1 numbered_list, 1 header, 284.6ms
# Speed: 15.7ms preprocess, 284.6ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 header, 1 footer, 264.5ms
# Speed: 7.7ms preprocess, 264.5ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 titles, 1 paragraph, 1 marked_list, 1 header, 1 footer, 278.1ms
# Speed: 12.0ms preprocess, 278.1ms inference, 1.8ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 table, 2 marked_lists, 1 header, 257.2ms
# Speed: 1.3ms preprocess, 257.2ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 table, 1 header, 257.2ms
# Speed: 8.6ms preprocess, 257.2ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 paragraph, 1 header, 1 footnote, 269.9ms
# Speed: 0.0ms preprocess, 269.9ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 1 table, 1 picture, 1 header, 1 footer, 246.3ms
# Speed: 7.6ms preprocess, 246.3ms inference, 1.1ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 3 paragraphs, 1 picture, 1 numbered_list, 1 header, 1 footer, 229.2ms
# Speed: 9.9ms preprocess, 229.2ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 2 marked_lists, 1 header, 1 footer, 251.6ms
# Speed: 5.6ms preprocess, 251.6ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 3 paragraphs, 1 marked_list, 1 header, 1 footer, 248.2ms
# Speed: 12.9ms preprocess, 248.2ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 marked_list, 1 header, 1 footer, 238.9ms
# Speed: 9.9ms preprocess, 238.9ms inference, 9.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 header, 225.9ms
# Speed: 7.4ms preprocess, 225.9ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 2 numbered_lists, 1 header, 244.1ms
# Speed: 16.5ms preprocess, 244.1ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 title, 1 paragraph, 1 marked_list, 1 header, 243.5ms
# Speed: 0.0ms preprocess, 243.5ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 numbered_list, 1 header, 1 footer, 241.7ms
# Speed: 12.5ms preprocess, 241.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 table, 1 marked_list, 1 header, 234.2ms
# Speed: 8.9ms preprocess, 234.2ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 titles, 4 paragraphs, 2 pictures, 1 numbered_list, 1 marked_list, 1 header, 237.7ms
# Speed: 7.0ms preprocess, 237.7ms inference, 2.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 6 paragraphs, 1 marked_list, 1 header, 276.1ms
# Speed: 6.0ms preprocess, 276.1ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 1 picture, 1 table_signature, 1 numbered_list, 1 header, 1 footer, 230.4ms
# Speed: 7.2ms preprocess, 230.4ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 header, 240.2ms
# Speed: 8.0ms preprocess, 240.2ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 paragraph, 1 table, 1 header, 239.6ms
# Speed: 6.0ms preprocess, 239.6ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 title, 1 paragraph, 1 header, 1 footer, 249.0ms
# Speed: 7.0ms preprocess, 249.0ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 1 header, 260.2ms
# Speed: 5.0ms preprocess, 260.2ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 numbered_list, 1 marked_list, 1 header, 251.8ms
# Speed: 8.0ms preprocess, 251.8ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 marked_list, 1 header, 238.3ms
# Speed: 8.0ms preprocess, 238.3ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 1 numbered_list, 1 footer, 260.6ms
# Speed: 9.0ms preprocess, 260.6ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 1 paragraph, 1 table, 1 picture, 1 header, 231.6ms
# Speed: 9.0ms preprocess, 231.6ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 table, 1 numbered_list, 2 marked_lists, 1 header, 1 footer, 244.4ms
# Speed: 6.0ms preprocess, 244.4ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 header, 227.1ms
# Speed: 7.0ms preprocess, 227.1ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 title, 1 picture, 1 numbered_list, 1 marked_list, 1 header, 1 footer, 259.4ms
# Speed: 7.1ms preprocess, 259.4ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 3 paragraphs, 2 numbered_lists, 1 header, 1 footer, 239.5ms
# Speed: 11.0ms preprocess, 239.5ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 titles, 2 paragraphs, 1 picture, 1 marked_list, 1 header, 1 footer, 252.1ms
# Speed: 10.5ms preprocess, 252.1ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 header, 256.9ms
# Speed: 6.0ms preprocess, 256.9ms inference, 1.1ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 title, 1 paragraph, 1 header, 248.5ms
# Speed: 10.0ms preprocess, 248.5ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 numbered_list, 1 header, 1 footer, 237.7ms
# Speed: 8.5ms preprocess, 237.7ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 footer, 251.5ms
# Speed: 7.6ms preprocess, 251.5ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 2 titles, 4 paragraphs, 1 table, 1 picture, 1 footer, 246.0ms
# Speed: 16.0ms preprocess, 246.0ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 numbered_list, 1 footer, 255.3ms
# Speed: 15.0ms preprocess, 255.3ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 picture, 1 footer, 263.4ms
# Speed: 10.8ms preprocess, 263.4ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 4 paragraphs, 1 footer, 257.6ms
# Speed: 15.0ms preprocess, 257.6ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 3 paragraphs, 1 picture, 1 footer, 257.9ms
# Speed: 11.0ms preprocess, 257.9ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 title, 2 paragraphs, 1 table, 1 marked_list, 1 footer, 255.1ms
# Speed: 9.0ms preprocess, 255.1ms inference, 2.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 table, 1 picture_signature, 1 footer, 262.2ms
# Speed: 9.8ms preprocess, 262.2ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 footer, 258.3ms
# Speed: 9.0ms preprocess, 258.3ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 1 footer, 254.6ms
# Speed: 5.0ms preprocess, 254.6ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 footer, 236.0ms
# Speed: 7.0ms preprocess, 236.0ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 table, 1 picture, 1 footer, 272.4ms
# Speed: 6.0ms preprocess, 272.4ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 1 picture, 1 footer, 257.9ms
# Speed: 8.1ms preprocess, 257.9ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 5 paragraphs, 1 footer, 260.3ms
# Speed: 9.8ms preprocess, 260.3ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 6 paragraphs, 1 picture, 1 footer, 232.1ms
# Speed: 7.0ms preprocess, 232.1ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 1 footer, 251.9ms
# Speed: 5.0ms preprocess, 251.9ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 3 paragraphs, 1 footer, 250.1ms
# Speed: 6.0ms preprocess, 250.1ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 table, 1 footer, 279.8ms
# Speed: 6.8ms preprocess, 279.8ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 4 paragraphs, 2 pictures, 1 footer, 226.1ms
# Speed: 8.0ms preprocess, 226.1ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 1 footer, 1 footnote, 250.4ms
# Speed: 7.0ms preprocess, 250.4ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 1 marked_list, 1 footer, 229.3ms
# Speed: 7.0ms preprocess, 229.3ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 picture, 1 footer, 1 footnote, 245.9ms
# Speed: 6.0ms preprocess, 245.9ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 table, 1 footer, 270.0ms
# Speed: 6.5ms preprocess, 270.0ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 title, 1 paragraph, 1 numbered_list, 1 footer, 1 footnote, 255.6ms
# Speed: 10.5ms preprocess, 255.6ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 footer, 300.4ms
# Speed: 7.8ms preprocess, 300.4ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 picture, 1 footer, 298.4ms
# Speed: 0.0ms preprocess, 298.4ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 table, 1 footer, 235.0ms
# Speed: 0.0ms preprocess, 235.0ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 5 paragraphs, 1 footer, 1 footnote, 287.5ms
# Speed: 0.0ms preprocess, 287.5ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 table, 1 picture, 1 table_signature, 1 marked_list, 1 footer, 252.2ms
# Speed: 0.0ms preprocess, 252.2ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 table, 1 footer, 235.3ms
# Speed: 15.6ms preprocess, 235.3ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 3 paragraphs, 1 footer, 1 footnote, 220.7ms
# Speed: 15.6ms preprocess, 220.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 1 table, 1 picture, 1 footer, 268.2ms
# Speed: 0.0ms preprocess, 268.2ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 4 paragraphs, 1 footer, 291.1ms
# Speed: 15.6ms preprocess, 291.1ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 footer, 1 footnote, 287.8ms
# Speed: 20.4ms preprocess, 287.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 title, 3 paragraphs, 1 picture, 1 footer, 317.3ms
# Speed: 11.8ms preprocess, 317.3ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 footer, 1 footnote, 313.3ms
# Speed: 15.7ms preprocess, 313.3ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 titles, 2 paragraphs, 314.3ms
# Speed: 15.6ms preprocess, 314.3ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 title, 5 paragraphs, 1 picture, 234.9ms
# Speed: 17.0ms preprocess, 234.9ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 7 paragraphs, 1 table, 1 table_signature, 219.8ms
# Speed: 15.6ms preprocess, 219.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 217.2ms
# Speed: 18.6ms preprocess, 217.2ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 5 paragraphs, 283.8ms
# Speed: 0.0ms preprocess, 283.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 3 paragraphs, 1 table, 1 picture, 236.8ms
# Speed: 0.0ms preprocess, 236.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 5 paragraphs, 1 picture, 235.3ms
# Speed: 0.0ms preprocess, 235.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 6 paragraphs, 1 table, 2 pictures, 267.1ms
# Speed: 15.6ms preprocess, 267.1ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 titles, 1 paragraph, 266.9ms
# Speed: 0.0ms preprocess, 266.9ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 251.7ms
# Speed: 15.6ms preprocess, 251.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 7 paragraphs, 1 picture, 252.1ms
# Speed: 16.4ms preprocess, 252.1ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 title, 2 paragraphs, 1 picture, 1 numbered_list, 235.8ms
# Speed: 0.0ms preprocess, 235.8ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 title, 5 paragraphs, 1 table, 235.3ms
# Speed: 0.0ms preprocess, 235.3ms inference, 15.6ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 titles, 4 paragraphs, 1 table, 2 pictures, 235.8ms
# Speed: 0.0ms preprocess, 235.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 2 numbered_lists, 219.7ms
# Speed: 15.6ms preprocess, 219.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 228.2ms
# Speed: 8.0ms preprocess, 228.2ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 title, 1 paragraph, 235.1ms
# Speed: 15.6ms preprocess, 235.1ms inference, 6.5ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 3 paragraphs, 219.7ms
# Speed: 15.6ms preprocess, 219.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 5 paragraphs, 1 table, 1 picture, 234.9ms
# Speed: 0.0ms preprocess, 234.9ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 2 paragraphs, 1 picture, 2 numbered_lists, 235.3ms
# Speed: 15.6ms preprocess, 235.3ms inference, 15.6ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 2 paragraphs, 235.3ms
# Speed: 0.0ms preprocess, 235.3ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 2 paragraphs, 236.1ms
# Speed: 0.0ms preprocess, 236.1ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 table, 235.7ms
# Speed: 0.0ms preprocess, 235.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 220.5ms
# Speed: 15.6ms preprocess, 220.5ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 titles, 1 paragraph, 2 pictures, 246.8ms
# Speed: 0.0ms preprocess, 246.8ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 titles, 2 paragraphs, 1 picture, 282.8ms
# Speed: 0.0ms preprocess, 282.8ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 title, 3 paragraphs, 251.5ms
# Speed: 11.0ms preprocess, 251.5ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 titles, 6 paragraphs, 1 picture, 241.3ms
# Speed: 10.0ms preprocess, 241.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 1 picture, 251.9ms
# Speed: 15.6ms preprocess, 251.9ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 1 header, 235.3ms
# Speed: 15.6ms preprocess, 235.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 5 paragraphs, 1 picture, 1 numbered_list, 1 marked_list, 1 header, 251.8ms
# Speed: 15.7ms preprocess, 251.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 picture, 1 header, 219.7ms
# Speed: 0.0ms preprocess, 219.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 header, 250.3ms
# Speed: 0.0ms preprocess, 250.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 titles, 1 paragraph, 1 picture, 1 numbered_list, 1 header, 1 footnote, 268.3ms
# Speed: 15.6ms preprocess, 268.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 5 paragraphs, 2 numbered_lists, 1 header, 235.5ms
# Speed: 0.0ms preprocess, 235.5ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 1 picture, 1 header, 235.4ms
# Speed: 0.0ms preprocess, 235.4ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 1 picture, 1 header, 218.0ms
# Speed: 9.5ms preprocess, 218.0ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 1 marked_list, 1 header, 267.1ms
# Speed: 0.0ms preprocess, 267.1ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 3 paragraphs, 1 table, 1 header, 253.0ms
# Speed: 0.0ms preprocess, 253.0ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 1 marked_list, 1 header, 2 footnotes, 270.0ms
# Speed: 0.0ms preprocess, 270.0ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 3 paragraphs, 1 header, 229.1ms
# Speed: 6.7ms preprocess, 229.1ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 picture, 1 header, 262.8ms
# Speed: 4.5ms preprocess, 262.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 5 paragraphs, 1 picture, 1 header, 235.9ms
# Speed: 13.5ms preprocess, 235.9ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 5 paragraphs, 1 header, 240.3ms
# Speed: 0.0ms preprocess, 240.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 6 paragraphs, 1 header, 236.3ms
# Speed: 0.0ms preprocess, 236.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 header, 2 footnotes, 231.5ms
# Speed: 5.0ms preprocess, 231.5ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 marked_list, 1 header, 267.0ms
# Speed: 0.0ms preprocess, 267.0ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 5 paragraphs, 1 header, 2 footnotes, 249.7ms
# Speed: 8.5ms preprocess, 249.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 table, 1 header, 235.3ms
# Speed: 0.0ms preprocess, 235.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 6 paragraphs, 1 picture, 1 numbered_list, 1 header, 235.3ms
# Speed: 10.8ms preprocess, 235.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 5 paragraphs, 1 picture, 1 header, 236.1ms
# Speed: 15.6ms preprocess, 236.1ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 5 paragraphs, 1 table, 1 header, 235.3ms
# Speed: 0.0ms preprocess, 235.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 5 paragraphs, 1 header, 1 footnote, 220.5ms
# Speed: 15.6ms preprocess, 220.5ms inference, 15.6ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 1 header, 1 footnote, 234.7ms
# Speed: 0.0ms preprocess, 234.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 3 paragraphs, 1 table, 1 header, 231.6ms
# Speed: 0.0ms preprocess, 231.6ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 1 picture, 1 header, 235.8ms
# Speed: 0.0ms preprocess, 235.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 1 header, 2 footnotes, 220.6ms
# Speed: 15.6ms preprocess, 220.6ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 titles, 2 paragraphs, 1 footnote, 220.2ms
# Speed: 0.0ms preprocess, 220.2ms inference, 15.5ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 235.7ms
# Speed: 0.0ms preprocess, 235.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 5 titles, 4 paragraphs, 1 picture, 249.4ms
# Speed: 2.0ms preprocess, 249.4ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 242.4ms
# Speed: 15.6ms preprocess, 242.4ms inference, 4.4ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 230.7ms
# Speed: 0.0ms preprocess, 230.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 2 marked_lists, 249.1ms
# Speed: 0.0ms preprocess, 249.1ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 marked_list, 236.2ms
# Speed: 15.6ms preprocess, 236.2ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 3 paragraphs, 267.4ms
# Speed: 15.6ms preprocess, 267.4ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 titles, 3 paragraphs, 238.2ms
# Speed: 0.0ms preprocess, 238.2ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 235.5ms
# Speed: 15.6ms preprocess, 235.5ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 4 paragraphs, 1 picture, 1 numbered_list, 235.8ms
# Speed: 0.0ms preprocess, 235.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 5 paragraphs, 1 numbered_list, 1 marked_list, 251.5ms
# Speed: 15.6ms preprocess, 251.5ms inference, 15.6ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 5 paragraphs, 1 table, 1 marked_list, 250.2ms
# Speed: 2.4ms preprocess, 250.2ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 marked_list, 266.6ms
# Speed: 15.6ms preprocess, 266.6ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 numbered_list, 1 footnote, 284.3ms
# Speed: 0.0ms preprocess, 284.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 table, 251.9ms
# Speed: 0.0ms preprocess, 251.9ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 titles, 4 paragraphs, 1 picture, 1 numbered_list, 245.9ms
# Speed: 0.0ms preprocess, 245.9ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 233.3ms
# Speed: 0.0ms preprocess, 233.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 1 footnote, 221.6ms
# Speed: 15.6ms preprocess, 221.6ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 titles, 3 paragraphs, 3 pictures, 220.3ms
# Speed: 13.5ms preprocess, 220.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 marked_list, 219.7ms
# Speed: 7.5ms preprocess, 219.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 1 marked_list, 242.7ms
# Speed: 0.0ms preprocess, 242.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 251.3ms
# Speed: 0.0ms preprocess, 251.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 titles, 2 paragraphs, 1 picture, 235.9ms
# Speed: 0.0ms preprocess, 235.9ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 1 paragraph, 1 numbered_list, 251.0ms
# Speed: 0.0ms preprocess, 251.0ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 3 paragraphs, 1 footnote, 235.7ms
# Speed: 0.0ms preprocess, 235.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 235.3ms
# Speed: 0.0ms preprocess, 235.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 1 numbered_list, 1 marked_list, 235.8ms
# Speed: 0.0ms preprocess, 235.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 table, 283.4ms
# Speed: 0.0ms preprocess, 283.4ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 titles, 3 paragraphs, 1 picture, 220.1ms
# Speed: 15.6ms preprocess, 220.1ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 4 paragraphs, 1 picture, 1 marked_list, 235.8ms
# Speed: 0.0ms preprocess, 235.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 titles, 2 paragraphs, 1 picture, 1 marked_list, 1 footnote, 268.6ms
# Speed: 0.0ms preprocess, 268.6ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 3 paragraphs, 1 footnote, 236.0ms
# Speed: 15.6ms preprocess, 236.0ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 4 paragraphs, 1 table, 1 picture, 1 table_signature, 235.3ms
# Speed: 15.6ms preprocess, 235.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 4 paragraphs, 1 table, 1 picture, 267.5ms
# Speed: 0.0ms preprocess, 267.5ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 titles, 2 paragraphs, 251.6ms
# Speed: 12.0ms preprocess, 251.6ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 3 paragraphs, 284.9ms
# Speed: 0.0ms preprocess, 284.9ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 1 picture, 2 numbered_lists, 251.4ms
# Speed: 16.0ms preprocess, 251.4ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 1 table, 237.1ms
# Speed: 15.6ms preprocess, 237.1ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 1 title, 1 paragraph, 1 table, 1 marked_list, 1 header, 252.0ms
# Speed: 0.0ms preprocess, 252.0ms inference, 13.5ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 picture, 1 picture_signature, 1 header, 235.9ms
# Speed: 0.0ms preprocess, 235.9ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 title, 3 paragraphs, 1 marked_list, 252.7ms
# Speed: 15.6ms preprocess, 252.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 table, 1 picture, 1 numbered_list, 235.3ms
# Speed: 0.0ms preprocess, 235.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 3 tables, 1 picture, 1 picture_signature, 220.3ms
# Speed: 15.6ms preprocess, 220.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 5 paragraphs, 2 pictures, 235.8ms
# Speed: 0.0ms preprocess, 235.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 header, 1 footnote, 252.3ms
# Speed: 15.6ms preprocess, 252.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 1 paragraph, 1 numbered_list, 1 footnote, 267.5ms
# Speed: 0.0ms preprocess, 267.5ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 3 paragraphs, 1 table, 1 picture, 2 numbered_lists, 235.3ms
# Speed: 0.0ms preprocess, 235.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 table, 1 header, 253.0ms
# Speed: 0.0ms preprocess, 253.0ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 3 paragraphs, 1 header, 2 footnotes, 235.2ms
# Speed: 0.0ms preprocess, 235.2ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 table, 1 picture, 1 marked_list, 1 header, 235.7ms
# Speed: 15.6ms preprocess, 235.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 1 picture, 1 header, 1 footnote, 221.7ms
# Speed: 14.0ms preprocess, 221.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 3 paragraphs, 1 table, 1 picture, 2 numbered_lists, 1 header, 220.1ms
# Speed: 15.6ms preprocess, 220.1ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 table, 1 header, 251.8ms
# Speed: 0.0ms preprocess, 251.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 5 paragraphs, 1 table, 1 picture, 1 header, 251.8ms
# Speed: 0.0ms preprocess, 251.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 1 table, 1 picture, 1 header, 267.3ms
# Speed: 0.0ms preprocess, 267.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 1 picture, 1 footnote, 251.8ms
# Speed: 8.0ms preprocess, 251.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 2 tables, 1 picture, 1 numbered_list, 241.3ms
# Speed: 11.3ms preprocess, 241.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 numbered_list, 1 footnote, 235.4ms
# Speed: 0.0ms preprocess, 235.4ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 2 titles, 1 paragraph, 1 marked_list, 1 header, 283.0ms
# Speed: 0.0ms preprocess, 283.0ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 picture, 1 numbered_list, 1 marked_list, 1 header, 264.5ms
# Speed: 3.0ms preprocess, 264.5ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 table, 1 header, 231.1ms
# Speed: 0.0ms preprocess, 231.1ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 2 pictures, 1 header, 1 footnote, 267.0ms
# Speed: 0.0ms preprocess, 267.0ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 title, 3 paragraphs, 1 picture, 1 header, 272.0ms
# Speed: 4.0ms preprocess, 272.0ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 4 paragraphs, 1 table, 1 header, 269.0ms
# Speed: 15.7ms preprocess, 269.0ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 header, 267.7ms
# Speed: 15.6ms preprocess, 267.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 title, 3 paragraphs, 2 pictures, 1 header, 251.8ms
# Speed: 15.6ms preprocess, 251.8ms inference, 15.6ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 title, 2 paragraphs, 1 table, 1 header, 268.9ms
# Speed: 15.6ms preprocess, 268.9ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 1 picture, 1 header, 253.3ms
# Speed: 16.1ms preprocess, 253.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 1 numbered_list, 1 header, 267.1ms
# Speed: 0.0ms preprocess, 267.1ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 1 table, 1 numbered_list, 1 header, 277.0ms
# Speed: 0.0ms preprocess, 277.0ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 1 paragraph, 1 header, 282.9ms
# Speed: 0.0ms preprocess, 282.9ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 2 tables, 1 header, 268.5ms
# Speed: 0.0ms preprocess, 268.5ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 1 table, 1 picture, 1 numbered_list, 1 header, 284.7ms
# Speed: 10.7ms preprocess, 284.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 header, 1 footnote, 283.4ms
# Speed: 0.0ms preprocess, 283.4ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 picture, 1 header, 1 footnote, 267.9ms
# Speed: 15.6ms preprocess, 267.9ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 3 paragraphs, 1 header, 275.3ms
# Speed: 9.6ms preprocess, 275.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 2 tables, 1 picture, 1 numbered_list, 1 header, 235.6ms
# Speed: 6.5ms preprocess, 235.6ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 1 table, 1 picture, 1 numbered_list, 1 header, 235.8ms
# Speed: 15.6ms preprocess, 235.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 1 table, 1 numbered_list, 1 header, 267.8ms
# Speed: 7.5ms preprocess, 267.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 2 tables, 1 picture, 1 header, 299.6ms
# Speed: 15.8ms preprocess, 299.6ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 4 paragraphs, 1 table, 1 picture, 1 header, 298.1ms
# Speed: 15.6ms preprocess, 298.1ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 titles, 3 paragraphs, 1 header, 1 footnote, 330.0ms
# Speed: 17.6ms preprocess, 330.0ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 2 titles, 3 paragraphs, 1 numbered_list, 1 header, 268.1ms
# Speed: 15.6ms preprocess, 268.1ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 title, 2 paragraphs, 1 header, 251.5ms
# Speed: 0.0ms preprocess, 251.5ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 768x960 4 paragraphs, 1 table, 1 picture, 1 header, 236.0ms
# Speed: 0.0ms preprocess, 236.0ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 picture, 1 header, 252.1ms
# Speed: 16.0ms preprocess, 252.1ms inference, 15.6ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 2 paragraphs, 1 picture, 1 numbered_list, 1 header, 3 footnotes, 255.3ms
# Speed: 12.7ms preprocess, 255.3ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 768x960 1 paragraph, 1 table, 2 pictures, 1 table_signature, 1 numbered_list, 1 header, 1 footnote, 251.8ms
# Speed: 15.6ms preprocess, 251.8ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 960)
#
# 0: 960x768 1 title, 1 paragraph, 1 table, 1 picture, 1 header, 236.6ms
# Speed: 0.0ms preprocess, 236.6ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 2 tables, 1 header, 332.7ms
# Speed: 15.6ms preprocess, 332.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 2 pictures, 1 header, 251.7ms
# Speed: 13.9ms preprocess, 251.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 5 paragraphs, 1 picture, 1 header, 233.4ms
# Speed: 0.0ms preprocess, 233.4ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 header, 268.7ms
# Speed: 0.0ms preprocess, 268.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 table, 1 header, 283.3ms
# Speed: 16.1ms preprocess, 283.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 table, 1 picture, 1 header, 281.6ms
# Speed: 11.0ms preprocess, 281.6ms inference, 3.5ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 2 tables, 1 picture, 1 header, 1 footnote, 284.2ms
# Speed: 11.9ms preprocess, 284.2ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 1 picture, 1 header, 270.0ms
# Speed: 13.7ms preprocess, 270.0ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 picture, 1 header, 2 footnotes, 269.2ms
# Speed: 0.0ms preprocess, 269.2ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 2 pictures, 1 header, 1 footnote, 252.5ms
# Speed: 0.0ms preprocess, 252.5ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 picture, 1 numbered_list, 1 marked_list, 1 header, 2 footnotes, 250.8ms
# Speed: 0.0ms preprocess, 250.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 3 paragraphs, 1 table, 1 header, 236.3ms
# Speed: 0.0ms preprocess, 236.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 table, 1 picture_signature, 1 marked_list, 1 header, 1 footnote, 233.6ms
# Speed: 19.5ms preprocess, 233.6ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 3 pictures, 1 picture_signature, 1 header, 1 footnote, 241.0ms
# Speed: 15.6ms preprocess, 241.0ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 768)
#
# ...
#
# 0: 960x768 1 title, 4 paragraphs, 1 picture, 267.0ms
# Speed: 0.0ms preprocess, 267.0ms inference, 3.5ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 220.1ms
# Speed: 15.7ms preprocess, 220.1ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 4 paragraphs, 1 table, 1 picture, 252.4ms
# Speed: 7.0ms preprocess, 252.4ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 picture, 229.7ms
# Speed: 0.0ms preprocess, 229.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 3 paragraphs, 224.0ms
# Speed: 15.6ms preprocess, 224.0ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 titles, 3 paragraphs, 1 picture, 1 marked_list, 257.0ms
# Speed: 0.0ms preprocess, 257.0ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 219.9ms
# Speed: 0.0ms preprocess, 219.9ms inference, 15.6ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 3 paragraphs, 1 picture, 251.8ms
# Speed: 15.6ms preprocess, 251.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 219.1ms
# Speed: 15.6ms preprocess, 219.1ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 1 paragraph, 1 table, 1 numbered_list, 251.8ms
# Speed: 15.6ms preprocess, 251.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 titles, 2 paragraphs, 1 table, 1 picture, 235.7ms
# Speed: 0.0ms preprocess, 235.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 1 numbered_list, 252.4ms
# Speed: 0.0ms preprocess, 252.4ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 235.3ms
# Speed: 0.0ms preprocess, 235.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 titles, 1 paragraph, 2 pictures, 235.3ms
# Speed: 0.0ms preprocess, 235.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 titles, 1 paragraph, 1 picture, 251.8ms
# Speed: 0.0ms preprocess, 251.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 235.8ms
# Speed: 15.6ms preprocess, 235.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 267.1ms
# Speed: 15.6ms preprocess, 267.1ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 223.7ms
# Speed: 15.6ms preprocess, 223.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 219.6ms
# Speed: 1.0ms preprocess, 219.6ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 titles, 4 paragraphs, 1 table, 1 picture, 266.6ms
# Speed: 0.0ms preprocess, 266.6ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 219.7ms
# Speed: 15.6ms preprocess, 219.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 269.5ms
# Speed: 15.0ms preprocess, 269.5ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 1 paragraph, 1 picture, 1 marked_list, 235.5ms
# Speed: 0.0ms preprocess, 235.5ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 4 paragraphs, 266.7ms
# Speed: 0.0ms preprocess, 266.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 6 paragraphs, 1 table, 220.1ms
# Speed: 15.6ms preprocess, 220.1ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 252.5ms
# Speed: 15.6ms preprocess, 252.5ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 3 paragraphs, 219.7ms
# Speed: 15.6ms preprocess, 219.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 4 paragraphs, 1 picture, 219.6ms
# Speed: 0.0ms preprocess, 219.6ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 3 paragraphs, 251.6ms
# Speed: 15.6ms preprocess, 251.6ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 3 paragraphs, 1 table, 223.2ms
# Speed: 15.6ms preprocess, 223.2ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 titles, 2 paragraphs, 234.9ms
# Speed: 15.6ms preprocess, 234.9ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 1 paragraph, 1 header, 1 footnote, 251.0ms
# Speed: 0.0ms preprocess, 251.0ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 picture, 1 header, 235.7ms
# Speed: 0.0ms preprocess, 235.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 2 pictures, 1 header, 220.2ms
# Speed: 15.6ms preprocess, 220.2ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 titles, 2 paragraphs, 1 header, 251.5ms
# Speed: 15.6ms preprocess, 251.5ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 titles, 3 paragraphs, 1 picture, 1 numbered_list, 1 header, 220.2ms
# Speed: 15.6ms preprocess, 220.2ms inference, 15.6ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 6 paragraphs, 1 header, 235.8ms
# Speed: 0.0ms preprocess, 235.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 marked_list, 1 header, 1 footnote, 251.7ms
# Speed: 16.0ms preprocess, 251.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 1 picture, 1 marked_list, 1 header, 2 footnotes, 219.6ms
# Speed: 0.0ms preprocess, 219.6ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 1 paragraph, 1 header, 1 footnote, 232.6ms
# Speed: 0.0ms preprocess, 232.6ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 1 picture, 1 header, 1 footnote, 255.1ms
# Speed: 0.0ms preprocess, 255.1ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 5 paragraphs, 1 picture, 1 picture_signature, 1 header, 220.0ms
# Speed: 12.5ms preprocess, 220.0ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 2 pictures, 1 marked_list, 1 header, 220.1ms
# Speed: 0.0ms preprocess, 220.1ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 marked_list, 1 header, 1 footnote, 235.2ms
# Speed: 12.4ms preprocess, 235.2ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 header, 237.0ms
# Speed: 0.0ms preprocess, 237.0ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 picture, 1 picture_signature, 1 marked_list, 1 header, 266.5ms
# Speed: 15.6ms preprocess, 266.5ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 1 table, 1 header, 1 footnote, 222.7ms
# Speed: 0.0ms preprocess, 222.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 1 paragraph, 1 header, 254.9ms
# Speed: 0.0ms preprocess, 254.9ms inference, 12.5ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 marked_list, 1 header, 217.7ms
# Speed: 18.4ms preprocess, 217.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 table, 1 picture, 1 marked_list, 1 header, 274.5ms
# Speed: 0.0ms preprocess, 274.5ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 4 paragraphs, 2 pictures, 1 numbered_list, 1 header, 216.1ms
# Speed: 4.0ms preprocess, 216.1ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 header, 1 footnote, 236.0ms
# Speed: 0.0ms preprocess, 236.0ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 2 pictures, 1 header, 251.9ms
# Speed: 15.6ms preprocess, 251.9ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 picture, 1 header, 1 footnote, 222.5ms
# Speed: 6.0ms preprocess, 222.5ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 titles, 2 paragraphs, 1 picture, 1 numbered_list, 1 header, 219.7ms
# Speed: 15.6ms preprocess, 219.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 1 paragraph, 1 header, 251.0ms
# Speed: 15.6ms preprocess, 251.0ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 header, 235.7ms
# Speed: 0.0ms preprocess, 235.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 table, 1 marked_list, 1 header, 251.8ms
# Speed: 16.0ms preprocess, 251.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 1 numbered_list, 1 marked_list, 1 header, 220.1ms
# Speed: 5.0ms preprocess, 220.1ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 titles, 2 paragraphs, 1 table, 1 numbered_list, 1 header, 1 footer, 267.0ms
# Speed: 0.0ms preprocess, 267.0ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 3 paragraphs, 1 table, 1 header, 1 footer, 217.0ms
# Speed: 17.0ms preprocess, 217.0ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 3 paragraphs, 1 picture, 1 header, 1 footer, 267.0ms
# Speed: 0.0ms preprocess, 267.0ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 1 picture, 1 numbered_list, 1 header, 1 footer, 219.7ms
# Speed: 15.6ms preprocess, 219.7ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 4 paragraphs, 1 header, 1 footer, 236.1ms
# Speed: 0.0ms preprocess, 236.1ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 table, 1 numbered_list, 1 header, 1 footer, 250.5ms
# Speed: 0.0ms preprocess, 250.5ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 header, 1 footer, 1 footnote, 220.5ms
# Speed: 9.0ms preprocess, 220.5ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 title, 2 paragraphs, 1 header, 1 footer, 266.9ms
# Speed: 15.6ms preprocess, 266.9ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 picture, 1 header, 1 footer, 221.0ms
# Speed: 8.5ms preprocess, 221.0ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 4 paragraphs, 1 table, 1 header, 1 footer, 223.9ms
# Speed: 15.6ms preprocess, 223.9ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 header, 1 footer, 250.9ms
# Speed: 0.0ms preprocess, 250.9ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 picture, 1 header, 1 footer, 220.1ms
# Speed: 15.6ms preprocess, 220.1ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 picture, 1 header, 1 footer, 1 footnote, 267.4ms
# Speed: 0.0ms preprocess, 267.4ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 header, 1 footer, 220.1ms
# Speed: 16.0ms preprocess, 220.1ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 2 paragraphs, 1 table, 1 picture, 1 header, 1 footer, 251.8ms
# Speed: 0.0ms preprocess, 251.8ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 header, 1 footer, 1 footnote, 236.4ms
# Speed: 0.0ms preprocess, 236.4ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 1 paragraph, 1 numbered_list, 1 header, 1 footer, 235.3ms
# Speed: 0.0ms preprocess, 235.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
#
# 0: 960x768 5 paragraphs, 1 picture, 1 header, 1 footer, 1 footnote, 251.3ms
# Speed: 15.1ms preprocess, 251.3ms inference, 0.0ms postprocess per image at shape (1, 3, 960, 768)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 89
#      86         y_pred.extend(pred_classes)
#      88 # 2. Рассчитываем метрики
# ---> 89 precision, recall, f1, _ = precision_recall_fscore_support(y_true, y_pred, average="weighted")
#      90 mIoU = average_precision_score(y_true, y_pred)  # Оценка mAP50-95 (приближённая)
#      91 fitness = (precision + recall + f1) / 3  # Условная метрика для общего качества
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1789, in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1626 """Compute precision, recall, F-measure and support for each class.
#    1627
#    1628 The precision is the ratio ``tp / (tp + fp)`` where ``tp`` is the number of
#    (...)
#    1786  array([2, 2, 2]))
#    1787 """
#    1788 _check_zero_division(zero_division)
# -> 1789 labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1791 # Calculate tp_sum, pred_sum, true_sum ###
#    1792 samplewise = average == "samples"
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1561, in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1558 if average not in average_options and average != "binary":
#    1559     raise ValueError("average has to be one of " + str(average_options))
# -> 1561 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    1562 # Convert to Python primitive type to avoid NumPy type / Python str
#    1563 # comparison. See https://github.com/numpy/numpy/issues/6784
#    1564 present_labels = unique_labels(y_true, y_pred).tolist()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:103, in _check_targets(y_true, y_pred)
#      76 """Check that y_true and y_pred belong to the same classification task.
#      77
#      78 This converts multiclass or binary types to a common shape, and raises a
#    (...)
#     100 y_pred : array or indicator matrix
#     101 """
#     102 xp, _ = get_namespace(y_true, y_pred)
# --> 103 check_consistent_length(y_true, y_pred)
#     104 type_true = type_of_target(y_true, input_name="y_true")
#     105 type_pred = type_of_target(y_pred, input_name="y_pred")
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:457, in check_consistent_length(*arrays)
#     455 uniques = np.unique(lengths)
#     456 if len(uniques) > 1:
# --> 457     raise ValueError(
#     458         "Found input variables with inconsistent numbers of samples: %r"
#     459         % [int(l) for l in lengths]
#     460     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [6683, 5586]

# %%
import os

# Путь к тестовому набору данных
test_data_path = r"C:\\Users\\Vito\\Jupyter\\Models\\test_2_grup_Tim"

# Проверяем существование необходимых папок
if not os.path.exists(os.path.join(test_data_path, "images")):
    raise FileNotFoundError(f"Папка с изображениями {os.path.join(test_data_path, 'images')} не найдена.")
if not os.path.exists(os.path.join(test_data_path, "labels")):
    raise FileNotFoundError(f"Папка с разметкой {os.path.join(test_data_path, 'labels')} не найдена.")

# Формируем YAML-строку с описанием тестового набора
test_data_yaml = (
    "path: " + test_data_path.replace("\\", "/") + "\n"
    "train: \"\"  # Пустой путь, так как обучение не требуется\n"
    "val: images\n"
    "names:\n"
    "  0: title\n"
    "  1: paragraph\n"
    "  2: table\n"
    "  3: picture\n"
    "  4: table_signature\n"
    "  5: picture_signature\n"
    "  6: numbered_list\n"
    "  7: marked_list\n"
    "  8: header\n"
    "  9: footer\n"
    "  10: footnote\n"
    "  11: formula\n"
)

# Сохраняем YAML-файл
yaml_path = os.path.join(test_data_path, "test.yaml")
with open(yaml_path, "w", encoding="utf-8") as file:
    file.write(test_data_yaml)

print(f"Файл YAML для тестового набора сохранён в: {yaml_path}")

# Выполняем валидацию на тестовом наборе
results = model.val(data=yaml_path)

# Получаем метрики из results_dict
metrics = results.results_dict

# Извлекаем precision и recall
precision = metrics['metrics/precision(B)']
recall = metrics['metrics/recall(B)']

# Вычисляем F1 Score
f1_score = 2 * (precision * recall) / (precision + recall)

# Извлекаем mIoU (mAP50-95)
mAP50_95 = metrics['metrics/mAP50-95(B)']

# Печатаем метрики
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1_score)
print("mIoU (mAP50-95):", mAP50_95)
print("Fitness:", metrics['fitness'])
# Out:
# Файл YAML для тестового набора сохранён в: C:\\Users\\Vito\\Jupyter\\Models\\test_2_grup_Tim\test.yaml
# Ultralytics 8.3.34  Python-3.11.9 torch-2.5.1+cpu CPU (AMD Ryzen 7 7840HS w/ Radeon 780M Graphics)
# val: Scanning C:\Users\Vito\Jupyter\Models\test_2_grup_Tim\labels... 1072 images, 0 backgrounds, 0 corrupt: 100%|██████
# val: New cache created: C:\Users\Vito\Jupyter\Models\test_2_grup_Tim\labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 67/67 [05:42
#                    all       1072       6683      0.563       0.42      0.453      0.311
#                  title        414        490      0.429      0.588      0.431      0.281
#              paragraph        910       1717       0.46      0.722       0.63      0.509
#                  table        282        298      0.772      0.792      0.809       0.59
#                picture        250        255       0.39      0.737      0.522      0.312
#        table_signature        226        240      0.217    0.00833      0.065     0.0539
#      picture_signature        250        255      0.727     0.0706      0.255      0.201
#          numbered_list        291        301      0.429      0.332      0.305      0.241
#            marked_list        381        399      0.568      0.338      0.416      0.332
#                 header       1072       1072      0.995      0.713      0.931      0.606
#                 footer        604        604          1      0.671      0.927      0.507
#               footnote        580        580      0.129     0.0586     0.0486     0.0315
#                formula        370        472      0.637    0.00754     0.0945     0.0625
# Speed: 1.5ms preprocess, 297.9ms inference, 0.0ms loss, 0.5ms postprocess per image
# Results saved to runs\detect\val3
# Precision: 0.5627063363398943
# Recall: 0.41983362840137023
# F1 Score: 0.4808823078707649
# mIoU (mAP50-95): 0.31063483164992645
# Fitness: 0.32485065976455385

# %%
Обработка test_3_grup_Tim...
